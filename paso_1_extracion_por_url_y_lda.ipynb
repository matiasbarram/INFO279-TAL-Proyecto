# %% [markdown]
# # Generando el dataset para el proyecto de clasificacion de noticias
#
# Utilizamos los archivos csv proporcionados para crear nuestro dataset inicial (disponibles en noticias)

# %%
import pandas as pd
from os import listdir
from os.path import join
from tqdm import tqdm
from my_funcs import clean_and_tag
import re
from pandasql import sqldf
import numpy as np

# %%
pd.read_csv('./noticias/chile_2021-01.csv').head(3)
# Out:
#         id country media_outlet  \
# 0  3816243   chile  elmostrador
# 1  3816387   chile  elmostrador
# 2  3816512   chile  elmostrador
#
#                                                                                                                        url  \
# 0  https://www.elmostrador.cl/dia/2021/01/01/ley-de-migracion-diputada-nunez-rn-formula-observaciones-al-tc-frente-a-re...
# 1  https://www.elmostrador.cl/destacado/2021/01/01/2021-arranca-con-3-588-nuevos-contagios-y-52-fallecidos-por-covid-19...
# 2  https://www.elmostrador.cl/dia/2021/01/01/829-personas-fueron-detenidas-durante-noche-de-ano-nuevo-327-de-ellas-en-h...
#
#                                                                                                                    title  \
# 0  Ley de Migración: diputada Núñez (RN) formula observaciones al TC frente a requerimiento ingresado por el FA, PC y PS
# 1         2021 arranca con 3.588 nuevos contagios y 52 fallecidos por Covid-19: alza de casos es la más alta desde julio
# 2                    829 personas fueron detenidas durante noche de Año Nuevo: 327 de ellas en horario de toque de queda
#
#                                                                                                                       text  \
# 0  La diputada y vicepresidenta de Renovación Nacional, Paulina Núñez, ingresará en los próximos días un escrito ante e...
# 1  Según el reporte de hoy, el Ministerio de Salud informa 3.588 casos nuevos de Covid-19 (la cifra más alta desde el 5...
# 2  Carabineros reportó que hasta las 06:00 am. de este viernes, efectivos policiales detuvieron a 829 personas a nivel ...
#
#          date    year  id_journalist
# 0  2021-01-01  2021.0            NaN
# 1  2021-01-01  2021.0            NaN
# 2  2021-01-01  2021.0            NaN

# %% [markdown]
#  Ya que estas noticias entregadas no se encuentran etiquetadas es necesario realizar un procesamiento previo para asignarles una categoria que nos permita entrenar y probar nuestros modelos de clasificación.
#
#  ### **Categorias a utilizar**: Se utilizarán las categorias propuestas en el enunciado del trabajo
#
# * 1- Mundo
# * 2- Economía
# * 3- Política y Conflictos
# * 4- Ciencias y Tecnología,
# * 5- Catástrofes y Accidentes,
# * 6- Cultura y Artes,
# * 7- Deporte,
# * 8- Ecología y Planeta,
# * 9- Crimen, delitos y Justicia,
# * 10- Salud
#
# ### Adoptamos dos estrategias para realizar esta tarea:
#
# 1. Asignarle una categoria a partir de la información de la url.
# 2. Utilizar LDA para encontrar topicos que correspondan a alguna categoria.

# %% [markdown]
# # 1. Etiquetado a partir de la informacion contenida en la url
#
# Debido a la gran cantidad de noticias, propusimos inicialmente utilizar esta metodologia para disminuir el trabajo inicial y aprovechando la propia información que nos proveen los medios de prensa.
#
# Todas las noticias en su URL vienen con una categoria propia del medio, aunque esta pueda diferir entre los medios (una misma noticias para un medio puede ser *nacional* pero para otro puede ser *cultura*) podemos clasificar incialmente utilizando esta información.

# %%
unique_url_tags = set()
folder = './noticias'
dfs = []
for archivo in tqdm(listdir(folder)):
    df = pd.read_csv(join(folder, archivo))
    corpus = clean_and_tag(df)
    dfs.append(corpus)
    for tag in corpus.tag.unique():
        unique_url_tags.add(tag)
# Out:
# 100%|█████████████████████████████████████████████| 8/8 [00:03<00:00,  2.14it/s]

# %%
print(len(unique_url_tags))
list(unique_url_tags)[:10]
# Out:
# 83
# ['ciudadanos-al-poder',
#  'Deportes',
#  'salud',
#  'animal',
#  'noticias',
#  'Nacional',
#  'editorial',
#  'reconstitucion',
#  'peru',
#  'programas']

# %% [markdown]
# ### Encontramos 83 tags distintos. Revisamos esta lista y asignamos manualmente una categoria a los url_tags que pertenecieran a alguna de las 10 categorias objetivo (este trabajo manual se encuentra en el archivo ```categorias - hojav2.csv```)

# %%
dm = pd.read_csv('./categorias - hojav2.csv')
dm.rename(columns={'Unnamed: 0':'tag'}, inplace=True)
vals = dm.iloc[:, 1:]
labels = vals[vals.max(axis=1)>0].idxmax(axis=1)
print(len(labels))
labels.head(5)
# Out:
# 40
# 1       8-Ecología_y_Planeta
# 2          6-Cultura_y_Artes
# 3    4-Ciencias_y_Tecnología
# 4    3-Política_y_Conflictos
# 8    4-Ciencias_y_Tecnología
# dtype: object

# %% [markdown]
# ### Utilizamos un diccionario para manejar de mejor manera las *tag_url* con las categorias propuestas

# %%
cats = pd.DataFrame(labels)
cats = cats.join(dm['tag'])
cats.rename(columns={0:'cat'}, inplace=True)
cats_dict = dict(zip(cats['tag'], cats['cat']))
list(cats_dict.items())[:5]
# Out:
# [('animal', '8-Ecología_y_Planeta'),
#  ('artes', '6-Cultura_y_Artes'),
#  ('Autos', '4-Ciencias_y_Tecnología'),
#  ('braga', '3-Política_y_Conflictos'),
#  ('ciencia-tecnologia', '4-Ciencias_y_Tecnología')]

# %% [markdown]
# Se agrega la columna ```category``` al dataframe rellenando con Nan.
# Creamos una columna *content* que contiene el título de la noticias más el cuerpo de esta.
# Esto se realizó debido a que el título contiene información sumamente importante la cual explica la idea principal de esta en muy pocas lineas de texto, por lo que utilizarla nos proporciona información útil para su clasificación.

# %%
df = pd.concat(dfs)
df.drop_duplicates(subset='url', keep='first', inplace=True)
df['category'] = df.apply(lambda row : cats_dict.get(row.tag, np.nan), axis=1)
#df['content'] = df['title'] + df['text']
df['content'] = df[['title', 'text']].agg('. '.join, axis=1)
df.head(3)
# Out:
#       id country media_outlet  \
# 0  12872   chile      horas24
# 3  12929   chile      horas24
# 4  12942   chile      horas24
#
#                                                                                                                        url  \
# 0    https://www.24horas.cl/nacional/gobierno-da-luz-verde-a-temporada-de-piscinas-y-anuncio-reapertura-de-tupahue-4554782
# 3  https://www.24horas.cl/nacional/subsecretaria-bown-la-defensoria-de-la-ninez-es-un-organo-autonomo-y-nos-gustaria-qu...
# 4  https://www.24horas.cl/nacional/contralor-jorge-bermudez-asume-como-presidente-de-la-junta-de-auditores-de-la-onu-45...
#
#                                                                                                             title  \
# 0                                   Gobierno da luz verde a temporada de piscinas y anunció reapertura de Tupahue
# 3  Subsecretaria Bown: "La Defensoría de la Niñez es un órgano autónomo y nos gustaría que se notara un poco más"
# 4                               Contralor Jorge Bermúdez asume como presidente de la Junta de Auditores de la ONU
#
#                                                                                                                       text  \
# 0  Con un acto en la piscina Tupahue, ubicada en el Parque Metropolitano, el Gobierno dio luz verde a la reapertura del...
# 3  "Entendemos que la Defensoría es un órgano autónomo y nos gustaría que se notara un poco más". Así comentó la subsec...
# 4  El contralor Jorge Bermúdez asumió este 1 de diciembre la presidencia de la Junta de Auditores de Naciones Unidas re...
#
#          date       tag category  \
# 0  2020-12-01  nacional      NaN
# 3  2020-12-01  nacional      NaN
# 4  2020-12-01  nacional      NaN
#
#                                                                                                                    content
# 0  Gobierno da luz verde a temporada de piscinas y anunció reapertura de Tupahue. Con un acto en la piscina Tupahue, ub...
# 3  Subsecretaria Bown: "La Defensoría de la Niñez es un órgano autónomo y nos gustaría que se notara un poco más". "Ent...
# 4  Contralor Jorge Bermúdez asume como presidente de la Junta de Auditores de la ONU. El contralor Jorge Bermúdez asumi...

# %% [markdown]
# Almacenamos 30.000 de las noticias cuyo *url_tag* era muy general o no nos servia para asignarle una categoria. A estas noticias en una segunda etapa le aplicaremos LDA  para poder etiquetarlas y asi aumentar la información de nuestro dataset inicial.

# %%
pd.set_option('display.max_colwidth', 120)
df = df[['id','url','title', 'content', 'category']]
unravel = df[df['category'].isna()]
(unravel.sample(n=30000, random_state=2)).to_csv('30k_sin_cat.csv')
df = df[df['category'].notna()]
final_df_link = df.drop(columns=['url'])
final_df_link.to_csv('final_df_link.csv', index=False)
final_df_link.head(3)
# Out:
#          id  \
# 14    13115
# 18    13183
# 125  614680
#
#                                                                                                                 title  \
# 14                    Vacunación en Chile empezaría primer trimestre del 2021 e incluiría a 15,2 millones de personas
# 18   Sernapesca: "Viabilidad del virus de infectar es muy baja" tras hallazgo de COVID-19 en paquete chileno en China
# 125                                                 Presidente de México asegura que la pandemia "no nos ha rebasado"
#
#                                                                                                                      content  \
# 14   Vacunación en Chile empezaría primer trimestre del 2021 e incluiría a 15,2 millones de personas.  Este martes, el Pr...
# 18   Sernapesca: "Viabilidad del virus de infectar es muy baja" tras hallazgo de COVID-19 en paquete chileno en China. La...
# 125  Presidente de México asegura que la pandemia "no nos ha rebasado". El presidente de México, Andrés Manuel López Obra...
#
#      category
# 14   10-Salud
# 18   10-Salud
# 125   1-Mundo

# %% [markdown]
# Luego de esto, podemos ver que pudimos etiquetar de buena manera una cantidad considerable de noticias, pero, existen categorias las cuales no pudimos proveerles una gran cantidad de noticias y existieron otras, particularmente la categoria *5- Catástrofes y Accidentes* que no fue posible, esto es debido a que los medios de prensa no tienen en sus URL una categoria para catastrofes o accidentes.
#
# Por otro lado de esta manera es posible que nuestro dataset este sesgado, por ejemplo, en la categoria de Salud, todas las noticias son apartir de Septiembre de 2020, fechas las cuales la gran mayoria de noticias son acerca de la pandemia del Coronavirus, por lo que noticias anteriores que quizás hablan de la influenza u otras enfermedades las cuales anteriormete eran comunes pero desde esta fecha no, no sea bien clasificadas por este metodo.

# %%
q="""SELECT category, count(*) FROM final_df_link GROUP BY category ORDER BY count(*) DESC;"""
url_cat_result=sqldf(q)
url_cat_result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1                    7-Deporte      6708
# 2      4-Ciencias_y_Tecnología      4225
# 3                   2-Economía      2636
# 4      3-Política_y_Conflictos      1923
# 5                     10-Salud       333
# 6            6-Cultura_y_Artes       185
# 7         8-Ecología_y_Planeta       135
# 8  9-Crimen_delitos_y_Justicia       130

# %% [markdown]
# # 2. Aplicación de LDA a noticias no clasificadas

# %% [markdown]
# A las 30.000 noticias que guaradmos antes le aplicamos LDA con 20, creemos que es un buen número para poder apreciar una diferencia entre los grupos formados, debido a la gran cantidad de noticias a analizar
#
# *alternativa: tomar una muestra aleatoria de unos 10k items y buscar el número de tópicos que entregue la mejor coherencia*

# %%
import re
from pprint import pprint
import nltk;
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
import string
# spacy for lemmatization
import spacy
# Plotting tools
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./30k_sin_cat.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head(3)
# Out:
#         id  \
# 0  7329456
# 1   181069
# 2  4829009
#
#                                                                                                                        url  \
# 0                                            https://www.meganoticias.cl/tendencias/320596-adamari-lopez-adelgaza-1ab.html
# 1  https://www.biobiochile.cl/noticias/nacional/region-metropolitana/2020/09/18/encuentran-cuerpo-de-medico-en-rio-san-...
# 2  https://www.latercera.com/nacional/noticia/intendente-de-la-rm-por-paro-de-camioneros-interrumpir-la-libre-circulaci...
#
#                                                                                                                   title  \
# 0                         Adamari López y su lucha contra el sobrepeso: "He sido como una montaña rusa que sube y baja"
# 1                                     Encuentran cuerpo de médico en río San José de Maipo: llevaba un mes desaparecido
# 2  Intendente de la RM por paro de camioneros: “Interrumpir la libre circulación de vías que son públicas es un delito”
#
#                                                                                                                    content  \
# 0  Adamari López y su lucha contra el sobrepeso: "He sido como una montaña rusa que sube y baja". La actriz y presentad...
# 1  Encuentran cuerpo de médico en río San José de Maipo: llevaba un mes desaparecido. En las últimas horas fue encontra...
# 2  Intendente de la RM por paro de camioneros: “Interrumpir la libre circulación de vías que son públicas es un delito”...
#
#    category
# 0       NaN
# 1       NaN
# 2       NaN

# %%
def sent_to_words(sentences):
    for sentence in tqdm(sentences, desc="sentences to words"):
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
stop_words = stopwords.words('spanish')
nlp = spacy.load('es_core_news_md', disable=['parser', 'ner'])
def remove_stopwords(texts):
    desc = "removing stopwords"
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in tqdm(texts, desc=desc)]

def make_bigrams(texts, bigram_mod):
    return [bigram_mod[doc] for doc in tqdm(texts, desc="making bigrams")]

def make_trigrams(texts, bigram_mod, trigram_mod):
    return [trigram_mod[bigram_mod[doc]] for doc in tqdm(texts, desc="making trigrams")]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in tqdm(texts, desc="lemmatization"):
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
def get_ngrams(data_words):
    print('getting n-grams...')
    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    return bigram, trigram, bigram_mod, trigram_mod

# %%
def get_lemmatized_data(df):
    data = df.content.values.tolist()
    data = [re.sub(r'\s+', ' ', sent) for sent in tqdm(data, desc="replacing whitespaces")]
    data_words = list(sent_to_words(data))
    bigram, trigram, bigram_mod, trigram_mod = get_ngrams(data_words)
    data_words_nostops = remove_stopwords(data_words)
    data_words_bigrams = make_bigrams(data_words_nostops, bigram_mod)
    data_lemmatized = lemmatization(data_words_bigrams,
                                    allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
    return data_lemmatized

# %%
import pickle
try:
    with open ('./data_lemmatized', 'rb') as fp:
        data_lemmatized = pickle.load(fp)
except FileNotFoundError:
    print('data_lemmatized not found...')
    data_lemmatized = get_lemmatized_data(df)
    with open('./data_lemmatized', 'wb') as fp:
        pickle.dump(data_lemmatized, fp)

# %% [markdown]
# ### Entrenamiento del modelo de tópico con LDA
#
# - Entrenaremos un primer modelo de tópicos buscando un modelo con 20 tópicos.

# %%
model_file = "./models/model_lda_20_topics.mm"
num_topics = 20
#lda_model = gensim.models.ldamodel.LdaModel.load("./models/model_lda_20_topics.mm", )

# %%
try:
    lda_model = gensim.models.ldamodel.LdaModel.load("./models/model_lda_20_topics.mm")
    id2word = corpora.Dictionary.load(model_file + ".id2word")  
except FileNotFoundError:
    id2word = corpora.Dictionary(data_lemmatized) 
    lda_model = gensim.models.ldamulticore.LdaMulticore(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=num_topics, 
                                           random_state=num_topics,
                                           chunksize=100,
                                           passes=10,
                                           per_word_topics=True,
                                                   workers=4)
    lda_model.save(model_file)
texts = data_lemmatized
#corpus = [id2word.doc2bow(text) for text in tqdm(texts)]
corpus = [id2word.doc2bow(text) for text in tqdm(texts)]
# Out:
# 100%|███████████████████████████████████| 30000/30000 [00:03<00:00, 9341.13it/s]

# %%
def format_topics_documents(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(tqdm(ldamodel[corpus])):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
df_dominant_topic = pd.read_csv('./df_dominant_topic.csv')
df_dominant_topic = df_dominant_topic[['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'text_list']]
df_dominant_topic.to_csv('./df_dominant_topic.csv', index=False)

# %%
try:
    df_dominant_topic = pd.read_csv('./df_dominant_topic.csv')
except FileNotFoundError:
    df_topic_sents_keywords = format_topics_documents(lda_model, corpus, texts)
    # Format
    df_dominant_topic = df_topic_sents_keywords.reset_index()
    df_dominant_topic.to_csv('./df_dominant_topic.csv', index=False)
finally:    
    display(df_dominant_topic.head(20))
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0             0             6.0              0.6294
# 1             1            12.0              0.6791
# 2             2            15.0              0.3296
# 3             3             8.0              0.3821
# 4             4             7.0              0.4914
# 5             5             6.0              0.8272
# 6             6             4.0              0.6721
# 7             7            16.0              0.3591
# 8             8             4.0              0.7228
# 9             9            15.0              0.7055
# 10           10            10.0              0.3499
# 11           11            10.0              0.5203
# 12           12            15.0              0.3300
# 13           13             5.0              0.3588
# 14           14             5.0              0.9891
# 15           15            15.0              0.2641
# 16           16             6.0              0.9822
# 17           17            12.0              0.6173
# 18           18             2.0              0.7568
# 19           19             8.0              0.4870
#
#                                                                                               Keywords  \
# 0              post_on, instagrama_post, view_this, post_shared, shared_by, ano, by, hijo, hacer, vida
# 1                     hecho, vehiculo, lugar, hombre, encontrar, persona, detenido, ano, joven, sujeto
# 2                                  hacer, decir, ver, creer, querer, gente, mas, persona, dar, tambien
# 3            servicio, producto, persona, encontrar, usuario, sistema, contar, realizar, empresa, hora
# 4                     chileno, ano, nuevo, primero, argentino, obra, mundo, serie, temporada, historia
# 5              post_on, instagrama_post, view_this, post_shared, shared_by, ano, by, hijo, hacer, vida
# 6              vacuna, salud, persona, dosis, primero, virus, paciente, decir, enfermedad, coronavirus
# 7   carabinero, persona, policial, general, violencia, detenido, hecho, personal, institucion, publico
# 8              vacuna, salud, persona, dosis, primero, virus, paciente, decir, enfermedad, coronavirus
# 9                                  hacer, decir, ver, creer, querer, gente, mas, persona, dar, tambien
# 10                       persona, paso, comuna, medida, fase, salud, cuarentena, plan, semana, permiso
# 11                       persona, paso, comuna, medida, fase, salud, cuarentena, plan, semana, permiso
# 12                                 hacer, decir, ver, creer, querer, gente, mas, persona, dar, tambien
# 13     proyecto, gobierno, ministro, ley, diputado, presidente, hacer, parlamentario, comision, retiro
# 14     proyecto, gobierno, ministro, ley, diputado, presidente, hacer, parlamentario, comision, retiro
# 15                                 hacer, decir, ver, creer, querer, gente, mas, persona, dar, tambien
# 16             post_on, instagrama_post, view_this, post_shared, shared_by, ano, by, hijo, hacer, vida
# 17                    hecho, vehiculo, lugar, hombre, encontrar, persona, detenido, ano, joven, sujeto
# 18                 caso, publico, delito, fiscal, fiscalia, ministerio, hecho, tribunal, ano, imputado
# 19           servicio, producto, persona, encontrar, usuario, sistema, contar, realizar, empresa, hora
#
#                                                                                                                   text_list
# 0   ['adamari_lopez', 'luchar', 'sobrepeso', 'montana_rusa', 'subir', 'bajo', 'actriz', 'presentadoro', 'vencio', 'cance...
# 1   ['encontrar', 'cuerpo', 'medico', 'llevar', 'mes', 'desaparecido', 'ultimas_hora', 'encontrado', 'maipo', 'cuerpo', ...
# 2   ['intendente', 'paro', 'camionero', 'interrumpir', 'libre', 'circulacion', 'via', 'publica', 'delito', 'intendente',...
# 3   ['dentro', 'dar', 'conocer', 'experiencia', 'usuario', 'navegar', 'consola', 'compartido', 'caracteristica', 'proxim...
# 4   ['homenajear', 'justicia', 'espada_acuna', 'primero', 'aniversario', 'nacimiento', 'justicia', 'mén', 'dedicado', 'd...
# 5   ['rafael_araneda', 'marcela_vacarezza', 'presentar', 'hijo', 'redes_social', 'animador', 'television', 'rafael_arane...
# 6   ['escapista', 'variante', 'africano', 'podrio', 'disminuir', 'eficacia', 'vacuna', 'segunda_ola', 'contagio', 'sudaf...
# 7   ['estruendo', 'alertar', 'comuna', 'rm', 'descartar', 'explosion', 'fabrico', 'domingo', 'fuerte_estruendo', 'alerto...
# 8   ['detalle', 'proceso', 'vacunacion', 'deposito', 'nivel', 'nacional', 'tarjeta', 'segundo', 'dosis', 'hoy', 'alegrio...
# 9   ['padre', 'separar', 'parte', 'llegar', 'terraza', 'cafe', 'reunir yo', 'cliente', 'empece', 'ver', 'semana_pasado',...
# 10  ['cifra', 'historico', 'calidad', 'aire', 'rm', 'mejoro', 'sustancialmente', 'cifra', 'historica', 'calidad', 'aire'...
# 11  ['seremi', 'investigar', 'rencar', 'organizado', 'dar', 'positivo', 'autoridad', 'salud', 'referir', 'encabezar', 's...
# 12  ['ministro', 'propuesto', 'tratar', 'traidor', 'luego', 'hablar', 'unidad', 'ministro', 'defensa', 'mario_desbord', ...
# 13  ['regla', 'debutante', 'ministro', 'interior', 'rodrigo_delgado', 'asegurar', 'materia', 'manifestación', 'poner', '...
# 14  ['declarar', 'reforma', 'oposicion', 'buscar', 'permitir', 'segundo_retiro', 'diferencia', 'proyecto', 'gobierno', '...
# 15  ['asesinar', 'revelar', 'momento', 'disparo', 'cantante', 'pasado', 'ano', 'marzo', 'arma', 'fuego', 'cantante', 'se...
# 16  ['power_peralta', 'presentar', 'hermana', 'menor', 'ano', 'sorprender', 'red', 'trav', 'redes_social', 'raul_peralto...
# 17  ['conductor', 'transantiago', 'bano', 'robar', 'bus', 'pasajero', 'adentro', 'tarde', 'lunes', 'bus', 'transatiago',...
# 18  ['absolvio', 'hombre', 'acusado', 'abuso_sexual', 'joven', 'ano', 'absuelto', 'hombre', 'acusado', 'abusar_sexualmen...
# 19  ['metro', 'abrio', 'puerta', 'funcionamiento', 'gratuito', 'abrio', 'puerta', 'hora', 'estar', 'operativo', 'servici...

# %%
df_topics = pd.concat([df.drop(columns=['category']), df_dominant_topic[['Dominant_Topic', 'Keywords', 'text_list']]], axis=1)

# %%
df_topics['Dominant_Topic'] = df_topics['Dominant_Topic'].astype(int)
df_topics.head(3)
# Out:
#         id  \
# 0  7329456
# 1   181069
# 2  4829009
#
#                                                                                                                        url  \
# 0                                            https://www.meganoticias.cl/tendencias/320596-adamari-lopez-adelgaza-1ab.html
# 1  https://www.biobiochile.cl/noticias/nacional/region-metropolitana/2020/09/18/encuentran-cuerpo-de-medico-en-rio-san-...
# 2  https://www.latercera.com/nacional/noticia/intendente-de-la-rm-por-paro-de-camioneros-interrumpir-la-libre-circulaci...
#
#                                                                                                                   title  \
# 0                         Adamari López y su lucha contra el sobrepeso: "He sido como una montaña rusa que sube y baja"
# 1                                     Encuentran cuerpo de médico en río San José de Maipo: llevaba un mes desaparecido
# 2  Intendente de la RM por paro de camioneros: “Interrumpir la libre circulación de vías que son públicas es un delito”
#
#                                                                                                                    content  \
# 0  Adamari López y su lucha contra el sobrepeso: "He sido como una montaña rusa que sube y baja". La actriz y presentad...
# 1  Encuentran cuerpo de médico en río San José de Maipo: llevaba un mes desaparecido. En las últimas horas fue encontra...
# 2  Intendente de la RM por paro de camioneros: “Interrumpir la libre circulación de vías que son públicas es un delito”...
#
#    Dominant_Topic  \
# 0               6
# 1              12
# 2              15
#
#                                                                                   Keywords  \
# 0  post_on, instagrama_post, view_this, post_shared, shared_by, ano, by, hijo, hacer, vida
# 1         hecho, vehiculo, lugar, hombre, encontrar, persona, detenido, ano, joven, sujeto
# 2                      hacer, decir, ver, creer, querer, gente, mas, persona, dar, tambien
#
#                                                                                                                  text_list
# 0  ['adamari_lopez', 'luchar', 'sobrepeso', 'montana_rusa', 'subir', 'bajo', 'actriz', 'presentadoro', 'vencio', 'cance...
# 1  ['encontrar', 'cuerpo', 'medico', 'llevar', 'mes', 'desaparecido', 'ultimas_hora', 'encontrado', 'maipo', 'cuerpo', ...
# 2  ['intendente', 'paro', 'camionero', 'interrumpir', 'libre', 'circulacion', 'via', 'publica', 'delito', 'intendente',...

# %% [markdown]
# # Análisis manual

# %%
from my_funcs import get_df_keywords
get_df_keywords(lda_model, num_topics)
# Out:
#                     0            1                2              3   \
# 0                 agua       region             caso      candidato
# 1            ambiental         zona          publico        partido
# 2               pueblo         hora           delito       primario
# 3            comunidad       biobio           fiscal  independiente
# 4   pueblos_originario          rio         fiscalia    candidatura
# 5           territorio     nacional       ministerio        alcalde
# 6               tierra      eclipse            hecho        acuerdo
# 7              derecho        sismo         tribunal             ir
# 8              mapuche        total              ano  constituyente
# 9                 isla       región         imputado       politico
# 10        organización    araucanio          abogado          nuevo
# 11             especie        norte      antecedente   presidencial
# 12      medio_ambiente         ruta      funcionario         sector
# 13   escanos_reservado  antofagasta  derechos_humano       distrito
# 14             planeta         lago            parte       eleccion
# 15                zona    kilometro          proceso      oposicion
# 16    pueblos_indigena     magnitud         justicia        tambien
# 17       internacional      atacama            penal       elección
# 18             indigén       arauco          octubre         unidad
# 19            indigena       evento          derecho             ex
# 20             escanos          sur            decir          pacto
# 21             acuerdo     regional         judicial          hacer
# 22           historico          ver            dicho          listo
# 23              dentro      generar            luego          lista
# 24             proceso     fenomeno          defensa          decir
#
#              4               5                6          7            8   \
# 0        vacuna        proyecto          post_on    chileno     servicio
# 1         salud        gobierno  instagrama_post        ano     producto
# 2       persona        ministro        view_this      nuevo      persona
# 3         dosis             ley      post_shared    primero    encontrar
# 4       primero        diputado        shared_by  argentino      usuario
# 5         virus      presidente              ano       obra      sistema
# 6      paciente           hacer               by      mundo       contar
# 7         decir   parlamentario             hijo      serie     realizar
# 8    enfermedad        comision            hacer  temporada      empresa
# 9   coronavirus          retiro             vida   historia         hora
# 10      estudio           fondo            nuevo   director        metro
# 11       medico         acuerdo              ver     contar         solo
# 12          ano           decir     redes_social      mejor        hacer
# 13       millón         reforma           actriz     ciudad       animal
# 14      tambien         senador           famoso       arte         tipo
# 15        mayor         persona             foto   nacional     alimento
# 16      proceso         primero          tambien      museo      acceder
# 17        hacer  constitucional          primero      ganar     problema
# 18       llegar         pensión           contar    artista  informacion
# 19          mas      iniciativo         seguidor   proyecto      tambien
# 20       riesgo         tambien            video     evento         dato
# 21    poblacion             hoy         cantante    cultura         caso
# 22  laboratorio  segundo_retiro            padre    virtual          red
# 23         caso          buscar         escribio   festival     explicar
# 24      recibir           nuevo            junto     premio   plataforma
#
#             9           10                11          12          13  \
# 0      colegio     persona        presidente       hecho         ano
# 1          ano        paso          ministro    vehiculo      millón
# 2    educacion      comuna          diputado       lugar       nuevo
# 3     profesor      medida          politico      hombre         mas
# 4   estudiante        fase                ex   encontrar       mayor
# 5        clase       salud             cargo     persona     estudio
# 6      tambien  cuarentena     parlamentario    detenido     tambien
# 7        salud        plan           senador         ano  desarrollo
# 8       alumno      semana              jefe       joven     empresa
# 9         nino     permiso             decir      sujeto       nivel
# 10  presencial   autoridad          gobierno        robo        solo
# 11      volver         fin          gabinete      muerte      social
# 12       decir   sanitario           defensa     victima       parte
# 13     escuela       hacer            moneda       luego     primero
# 14       hacer        hora  sebastian_pinera     detener    explicar
# 15     escolar       lunes            pinero      delito       mundo
# 16     trabajo      quedar             luego    fiscalia    programa
# 17   condición     tambien        mandatario   homicidio     sistema
# 18   actividad        solo         renunciar      fiscal        país
# 19     familia       toque            equipo   detencion   economico
# 20     proceso    contagio             dejar         dar         mes
# 21     acceder    realizar           partido        arma         vez
# 22      prueba       común          interior    imputado    nacional
# 23       tomar       salir           general    personal   principal
# 24       forma       decir        secretario  carabinero  cientifico
#
#                          14        15                16             17  \
# 0                     mujer     hacer        carabinero        alcalde
# 1                     menor     decir           persona         sector
# 2                    genero       ver          policial       incendio
# 3                 violencia     creer           general     trabajador
# 4               adolescente    querer         violencia         vecino
# 5                      nino     gente          detenido      municipio
# 6                  servicio       mas             hecho          común
# 7                      edad   persona          personal       trabajar
# 8                talcahuano       dar       institucion        trabajo
# 9                   familia   tambien           publico        bombero
# 10                 hospital      bien          interior       vivienda
# 11                  victima      solo     manifestación  municipalidad
# 12                     obra     tener             grupo    funcionario
# 13               residencia      cosa          director        empresa
# 14                 familiar       hoy             lugar       regional
# 15                   sexual       vez           policia      municipal
# 16                 denuncia    hablar       carabineros          lugar
# 17                denunciar     vivir           octubre      autoridad
# 18                 maltrato     pasar  estallido_social          salud
# 19                   sename   siempre           control     emergencia
# 20                    hogar      vida         incidente         comuna
# 21                      ano   momento            sector       afectado
# 22                   medico       ano              hora     valparaiso
# 23                    madre  entonces           tambien          parte
# 24  violencia_intrafamiliar     ahora            ataque       servicio
#
#                 18            19
# 0       plebiscito          caso
# 1             voto         nuevo
# 2            votar      contagio
# 3          proceso         total
# 4       presidente         cifra
# 5         politico         salud
# 6        electoral       persona
# 7          octubre         nivel
# 8          apruebo       aumento
# 9         votacion        región
# 10           nuevo      nacional
# 11        elección  casos_activo
# 12         derecho        numero
# 13       resultado        region
# 14         rechazo        semana
# 15    constitucion     registrar
# 16   constituyente         mayor
# 17         persona      paciente
# 18   participacion     fallecido
# 19           local          alto
# 20            mesa        ultimo
# 21      democracia        comuna
# 22         domingo   coronavirus
# 23  constitucional          tasa
# 24       ciudadano     encontrar

# %% [markdown]
#     1- Mundo
#     2- Economía
#     3- Política y Conflictos
#     4- Ciencias y Tecnología,
#     5- Catástrofes y Accidentes,
#     6- Cultura y Artes,
#     7- Deporte,
#     8- Ecología y Planeta,
#     9- Crimen, delitos y Justicia,
#     10- Salud

# %% [markdown]
# Analizando los 20 tópicos determinamos que cada uno de estos corresponde a las siguentes categorías propuestas.
#
# Algunos tópicos como el 6, 13 y 19 serán procesados con LDA nuevamente para poder mejorar su clasificación debido a que en esta primera instancia no fue posible clasificarlos de buena manera.

# %%
url_cat_result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1                    7-Deporte      6708
# 2      4-Ciencias_y_Tecnología      4225
# 3                   2-Economía      2636
# 4      3-Política_y_Conflictos      1923
# 5                     10-Salud       333
# 6            6-Cultura_y_Artes       185
# 7         8-Ecología_y_Planeta       135
# 8  9-Crimen_delitos_y_Justicia       130

# %%
# nos importan mas aquellas categorias menos numerosas
cats_dict = {1 : '8-Ecología_y_Planeta', # importante
             2 : '9-Crimen_delitos_y_Justicia', # importante
             3 : '3-Política_y_Conflictos',
             4 : '10-Salud', # importante 
             5 : '3-Política_y_Conflictos',
             7 : '6-Cultura_y_Artes', # importante
             11 : '3-Política_y_Conflictos',
             12 : '9-Crimen_delitos_y_Justicia', #importante
             14 : '9-Crimen_delitos_y_Justicia', #importante
             16 : '9-Crimen_delitos_y_Justicia', #importante
             17 : '5-Catástrofes_y_Accidentes', # importante
             18 : '3-Política_y_Conflictos',}

# el resto aun sin categoria
for i in range(0, num_topics):
    if i not in cats_dict.keys():
        cats_dict[i] = np.nan
        
cats_dict
df_topics['category'] = df_topics.apply(lambda row : cats_dict[row.Dominant_Topic], axis=1)
df_topics.head(10)
# Out:
#          id  \
# 0   7329456
# 1    181069
# 2   4829009
# 3   6343140
# 4   3808041
# 5   7355093
# 6   6321224
# 7  13387486
# 8  13396327
# 9   6321215
#
#                                                                                                                        url  \
# 0                                            https://www.meganoticias.cl/tendencias/320596-adamari-lopez-adelgaza-1ab.html
# 1  https://www.biobiochile.cl/noticias/nacional/region-metropolitana/2020/09/18/encuentran-cuerpo-de-medico-en-rio-san-...
# 2  https://www.latercera.com/nacional/noticia/intendente-de-la-rm-por-paro-de-camioneros-interrumpir-la-libre-circulaci...
# 3  https://www.latercera.com/que-pasa/noticia/asi-es-playstation-5-por-dentro-dan-a-conocer-la-experiencia-que-tendra-e...
# 4  https://www.meganoticias.cl/nacional/324205-doodle-google-homenaje-justicia-espada-acuna-mena-ingeniera-civl-mgx17.html
# 5  https://www.meganoticias.cl/tendencias/313371-rafael-araneda-y-marcela-vacarezza-presentaron-a-su-hijo-benjamin-rafa...
# 6  https://www.latercera.com/que-pasa/noticia/mutacion-escapista-variante-africana-del-coronavirus-podria-disminuir-la-...
# 7                    https://www.emol.com/noticias/Nacional/2021/02/07/1011585/estruendo-comunas-Region-Metropolitana.html
# 8                   https://www.emol.com/noticias/Nacional/2021/01/28/1010630/Presidentes-detalles-proceso-vacunacion.html
# 9  https://www.latercera.com/que-pasa/noticia/mis-padres-se-separaron-en-pandemia-que-hago-con-mi-papa-2-parte/HIWR4HNF...
#
#                                                                                                                   title  \
# 0                         Adamari López y su lucha contra el sobrepeso: "He sido como una montaña rusa que sube y baja"
# 1                                     Encuentran cuerpo de médico en río San José de Maipo: llevaba un mes desaparecido
# 2  Intendente de la RM por paro de camioneros: “Interrumpir la libre circulación de vías que son públicas es un delito”
# 3          Así es PlayStation 5 por dentro: dan a conocer la experiencia que tendrá el usuario al navegar en la consola
# 4                                         Google homenajea a Justicia Espada Acuña, la primera ingeniera civil del país
# 5                                              Rafael Araneda y Marcela Vacarezza presentaron a su hijo Benjamín Rafael
# 6                     “Mutación escapista”: Variante africana del coronavirus podría disminuir la eficacia de la vacuna
# 7         Estruendo alerta a varias comunas de la RM: Bomberos descarta explosión en fábrica de pinturas en San Joaquín
# 8                 Los detalles del proceso de vacunación: 26 depósitos a nivel nacional y tarjeta para la segunda dosis
# 9                                                Mis padres se separaron en pandemia… ¿qué hago con mi papá? (2ª parte)
#
#                                                                                                                    content  \
# 0  Adamari López y su lucha contra el sobrepeso: "He sido como una montaña rusa que sube y baja". La actriz y presentad...
# 1  Encuentran cuerpo de médico en río San José de Maipo: llevaba un mes desaparecido. En las últimas horas fue encontra...
# 2  Intendente de la RM por paro de camioneros: “Interrumpir la libre circulación de vías que son públicas es un delito”...
# 3  Así es PlayStation 5 por dentro: dan a conocer la experiencia que tendrá el usuario al navegar en la consola. Sony I...
# 4  Google homenajea a Justicia Espada Acuña, la primera ingeniera civil del país. Para conmemorar el 128° aniversario d...
# 5  Rafael Araneda y Marcela Vacarezza presentaron a su hijo Benjamín Rafael. En redes sociales, los animadores de telev...
# 6  “Mutación escapista”: Variante africana del coronavirus podría disminuir la eficacia de la vacuna. La segunda ola de...
# 7  Estruendo alerta a varias comunas de la RM: Bomberos descarta explosión en fábrica de pinturas en San Joaquín. La no...
# 8  Los detalles del proceso de vacunación: 26 depósitos a nivel nacional y tarjeta para la segunda dosis. "Hoy es un dí...
# 9  Mis padres se separaron en pandemia… ¿qué hago con mi papá? (2ª parte). A las 11.59 llegué a la terraza de un café p...
#
#    Dominant_Topic  \
# 0               6
# 1              12
# 2              15
# 3               8
# 4               7
# 5               6
# 6               4
# 7              16
# 8               4
# 9              15
#
#                                                                                              Keywords  \
# 0             post_on, instagrama_post, view_this, post_shared, shared_by, ano, by, hijo, hacer, vida
# 1                    hecho, vehiculo, lugar, hombre, encontrar, persona, detenido, ano, joven, sujeto
# 2                                 hacer, decir, ver, creer, querer, gente, mas, persona, dar, tambien
# 3           servicio, producto, persona, encontrar, usuario, sistema, contar, realizar, empresa, hora
# 4                    chileno, ano, nuevo, primero, argentino, obra, mundo, serie, temporada, historia
# 5             post_on, instagrama_post, view_this, post_shared, shared_by, ano, by, hijo, hacer, vida
# 6             vacuna, salud, persona, dosis, primero, virus, paciente, decir, enfermedad, coronavirus
# 7  carabinero, persona, policial, general, violencia, detenido, hecho, personal, institucion, publico
# 8             vacuna, salud, persona, dosis, primero, virus, paciente, decir, enfermedad, coronavirus
# 9                                 hacer, decir, ver, creer, querer, gente, mas, persona, dar, tambien
#
#                                                                                                                  text_list  \
# 0  ['adamari_lopez', 'luchar', 'sobrepeso', 'montana_rusa', 'subir', 'bajo', 'actriz', 'presentadoro', 'vencio', 'cance...
# 1  ['encontrar', 'cuerpo', 'medico', 'llevar', 'mes', 'desaparecido', 'ultimas_hora', 'encontrado', 'maipo', 'cuerpo', ...
# 2  ['intendente', 'paro', 'camionero', 'interrumpir', 'libre', 'circulacion', 'via', 'publica', 'delito', 'intendente',...
# 3  ['dentro', 'dar', 'conocer', 'experiencia', 'usuario', 'navegar', 'consola', 'compartido', 'caracteristica', 'proxim...
# 4  ['homenajear', 'justicia', 'espada_acuna', 'primero', 'aniversario', 'nacimiento', 'justicia', 'mén', 'dedicado', 'd...
# 5  ['rafael_araneda', 'marcela_vacarezza', 'presentar', 'hijo', 'redes_social', 'animador', 'television', 'rafael_arane...
# 6  ['escapista', 'variante', 'africano', 'podrio', 'disminuir', 'eficacia', 'vacuna', 'segunda_ola', 'contagio', 'sudaf...
# 7  ['estruendo', 'alertar', 'comuna', 'rm', 'descartar', 'explosion', 'fabrico', 'domingo', 'fuerte_estruendo', 'alerto...
# 8  ['detalle', 'proceso', 'vacunacion', 'deposito', 'nivel', 'nacional', 'tarjeta', 'segundo', 'dosis', 'hoy', 'alegrio...
# 9  ['padre', 'separar', 'parte', 'llegar', 'terraza', 'cafe', 'reunir yo', 'cliente', 'empece', 'ver', 'semana_pasado',...
#
#                       category
# 0                          NaN
# 1  9-Crimen_delitos_y_Justicia
# 2                          NaN
# 3                          NaN
# 4            6-Cultura_y_Artes
# 5                          NaN
# 6                     10-Salud
# 7  9-Crimen_delitos_y_Justicia
# 8                     10-Salud
# 9                          NaN

# %%
final_df_topics = df_topics[['id','url','title', 'content', 'category']]
final_df_topics = final_df_topics[final_df_topics['category'].notna()]
final_df_topics.drop(columns=['url'], inplace=True)
final_df_topics.to_csv('final_df_topic.csv', index=False)
final_df_topics.head(3)
# Out:
#         id  \
# 1   181069
# 4  3808041
# 6  6321224
#
#                                                                                                title  \
# 1                  Encuentran cuerpo de médico en río San José de Maipo: llevaba un mes desaparecido
# 4                      Google homenajea a Justicia Espada Acuña, la primera ingeniera civil del país
# 6  “Mutación escapista”: Variante africana del coronavirus podría disminuir la eficacia de la vacuna
#
#                                                                                                                    content  \
# 1  Encuentran cuerpo de médico en río San José de Maipo: llevaba un mes desaparecido. En las últimas horas fue encontra...
# 4  Google homenajea a Justicia Espada Acuña, la primera ingeniera civil del país. Para conmemorar el 128° aniversario d...
# 6  “Mutación escapista”: Variante africana del coronavirus podría disminuir la eficacia de la vacuna. La segunda ola de...
#
#                       category
# 1  9-Crimen_delitos_y_Justicia
# 4            6-Cultura_y_Artes
# 6                     10-Salud

# %%
final_df_link = pd.read_csv('final_df_link.csv')
final_df_link.head(3)
# Out:
#        id  \
# 0   13115
# 1   13183
# 2  614680
#
#                                                                                                               title  \
# 0                   Vacunación en Chile empezaría primer trimestre del 2021 e incluiría a 15,2 millones de personas
# 1  Sernapesca: "Viabilidad del virus de infectar es muy baja" tras hallazgo de COVID-19 en paquete chileno en China
# 2                                                 Presidente de México asegura que la pandemia "no nos ha rebasado"
#
#                                                                                                                    content  \
# 0  Vacunación en Chile empezaría primer trimestre del 2021 e incluiría a 15,2 millones de personas.  Este martes, el Pr...
# 1  Sernapesca: "Viabilidad del virus de infectar es muy baja" tras hallazgo de COVID-19 en paquete chileno en China. La...
# 2  Presidente de México asegura que la pandemia "no nos ha rebasado". El presidente de México, Andrés Manuel López Obra...
#
#    category
# 0  10-Salud
# 1  10-Salud
# 2   1-Mundo

# %%
q="""SELECT category, count(*) FROM final_df_link GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1                    7-Deporte      6708
# 2      4-Ciencias_y_Tecnología      4225
# 3                   2-Economía      2636
# 4      3-Política_y_Conflictos      1923
# 5                     10-Salud       333
# 6            6-Cultura_y_Artes       185
# 7         8-Ecología_y_Planeta       135
# 8  9-Crimen_delitos_y_Justicia       130

# %%
q="""SELECT category, count(*) FROM final_df_topics GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0  9-Crimen_delitos_y_Justicia      8083
# 1      3-Política_y_Conflictos      5732
# 2                     10-Salud      1571
# 3   5-Catástrofes_y_Accidentes      1245
# 4         8-Ecología_y_Planeta       545
# 5            6-Cultura_y_Artes       357

# %%
final_df = pd.concat([final_df_link, final_df_topics]).reset_index().drop(columns=['index'])

# %%
q="""SELECT category, count(*) FROM final_df GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1  9-Crimen_delitos_y_Justicia      8213
# 2      3-Política_y_Conflictos      7655
# 3                    7-Deporte      6708
# 4      4-Ciencias_y_Tecnología      4225
# 5                   2-Economía      2636
# 6                     10-Salud      1904
# 7   5-Catástrofes_y_Accidentes      1245
# 8         8-Ecología_y_Planeta       680
# 9            6-Cultura_y_Artes       542

# %%
final_df.to_csv('final_df_paso1.csv', index=False)

# %%
df_sin_topic = df_topics[df_topics.category.isna()]
len(df_sin_topic)
# Out:
# 12467

# %% [markdown]
# Cerca del 40% del dataset sin categoría (post revision de urls) quedó con un tópico al que no pudimos asignarle una de nuestras categorías objetivo.
#
# Adoptaremos dos enfoques diferentes para tratar de etiquetar correctamente estas noticias, priorizando las categorías menos numerosas con el objetivo de obtener un dataset relativamente balanceado.

# %% [markdown]
# ### LDA al subset completo

# %%
df_sin_topic.to_csv('df_sin_topic.csv', index=False)

# %% [markdown]
# # Clasificacion de subtopicos en el cuadernillo 2. ***paso_2_re_extraccion_lda.ipynb***
