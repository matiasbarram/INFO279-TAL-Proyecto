# %% [markdown]
# # Generando el dataset para el proyecto de clasificación de noticias
#
# Utilizamos los archivos csv proporcionados para crear nuestro dataset inicial (disponibles en noticias)

# %%
import pandas as pd
from os import listdir
from os.path import join
from tqdm import tqdm
from my_funcs import clean_and_tag
import re
from pandasql import sqldf
import numpy as np

# %%
pd.read_csv('./noticias/chile_2021-01.csv').head(3)
# Out:
#         id country media_outlet  \
# 0  3816243   chile  elmostrador
# 1  3816387   chile  elmostrador
# 2  3816512   chile  elmostrador
#
#                                                  url  \
# 0  https://www.elmostrador.cl/dia/2021/01/01/ley-...
# 1  https://www.elmostrador.cl/destacado/2021/01/0...
# 2  https://www.elmostrador.cl/dia/2021/01/01/829-...
#
#                                                title  \
# 0  Ley de Migración: diputada Núñez (RN) formula ...
# 1  2021 arranca con 3.588 nuevos contagios y 52 f...
# 2  829 personas fueron detenidas durante noche de...
#
#                                                 text        date    year  \
# 0  La diputada y vicepresidenta de Renovación Nac...  2021-01-01  2021.0
# 1  Según el reporte de hoy, el Ministerio de Salu...  2021-01-01  2021.0
# 2  Carabineros reportó que hasta las 06:00 am. de...  2021-01-01  2021.0
#
#    id_journalist
# 0            NaN
# 1            NaN
# 2            NaN

# %% [markdown]
#  Ya que estas noticias no se encuentran etiquetadas, es necesario realizar un procesamiento previo para asignarles una categoría que nos permita entrenar y probar nuestros modelos de clasificación.
#
#  ### **Categorías a utilizar**: Se utilizarán las categorias propuestas en el enunciado del trabajo
#
# * 1- Mundo
# * 2- Economía
# * 3- Política y Conflictos
# * 4- Ciencias y Tecnología,
# * 5- Catástrofes y Accidentes,
# * 6- Cultura y Artes,
# * 7- Deporte,
# * 8- Ecología y Planeta,
# * 9- Crimen, delitos y Justicia,
# * 10- Salud
#
# ### Adoptamos dos estrategias para realizar esta tarea:
#
# 1. Asignarle una categoría a partir de la información de la url.
# 2. Utilizar LDA para encontrar tópicos que correspondan a alguna categoría.

# %% [markdown]
# # 1. Etiquetado a partir de la información contenida en la url.
#
# Debido a la gran cantidad de noticias, propusimos inicialmente utilizar esta metodología para disminuir el trabajo inicial y aprovechando la propia información que nos proveen los medios de prensa.
#
# Todas las noticias en su URL vienen con una categoria propia del medio, aunque esta pueda diferir entre los medios (una misma noticias para un medio puede ser *nacional* pero para otro puede ser *cultura*) podemos clasificar inicialmente utilizando esta información.

# %%
unique_url_tags = set()
folder = './noticias'
dfs = []
for archivo in tqdm(listdir(folder)):
    df = pd.read_csv(join(folder, archivo))
    corpus = clean_and_tag(df)
    dfs.append(corpus)
    for tag in corpus.tag.unique():
        unique_url_tags.add(tag)
# Out:
# 100%|██████████| 8/8 [00:03<00:00,  2.38it/s]

# %%
print(len(unique_url_tags))
list(unique_url_tags)[:10]
# Out:
# 83
# ['mineria',
#  'sin-editar',
#  'artes',
#  'la-tercera-pm',
#  'turismo',
#  'economia',
#  'calidad-de-vida',
#  'mouse',
#  'noticias',
#  'programas']

# %% [markdown]
# #### Encontramos **83** tags distintos. Revisamos esta lista y asignamos manualmente una categoría a los url_tags que pertenecieran a alguna de las 10 categorías objetivo (este trabajo manual se encuentra en el archivo ```categorias - hojav2.csv```)

# %%
dm = pd.read_csv('./intermediate_data/categorias - hojav2.csv')
dm.rename(columns={'Unnamed: 0':'tag'}, inplace=True)
vals = dm.iloc[:, 1:]
labels = vals[vals.max(axis=1)>0].idxmax(axis=1)
print(len(labels))
labels.head(5)
# Out:
# 40
# 1       8-Ecología_y_Planeta
# 2          6-Cultura_y_Artes
# 3    4-Ciencias_y_Tecnología
# 4    3-Política_y_Conflictos
# 8    4-Ciencias_y_Tecnología
# dtype: object

# %% [markdown]
# ### Utilizamos un diccionario para manejar de mejor manera las *tag_url* con las categorías propuestas

# %%
cats = pd.DataFrame(labels)
cats = cats.join(dm['tag'])
cats.rename(columns={0:'cat'}, inplace=True)
cats_dict = dict(zip(cats['tag'], cats['cat']))
list(cats_dict.items())[:5]
# Out:
# [('animal', '8-Ecología_y_Planeta'),
#  ('artes', '6-Cultura_y_Artes'),
#  ('Autos', '4-Ciencias_y_Tecnología'),
#  ('braga', '3-Política_y_Conflictos'),
#  ('ciencia-tecnologia', '4-Ciencias_y_Tecnología')]

# %% [markdown]
# Se agrega la columna ```category``` al dataframe rellenando con NaN.
# Creamos una columna *content* que contiene el título de la noticias más el cuerpo de esta.
# Esto se realizó debido a que el título contiene información sumamente importante la cual explica la idea principal de esta en muy pocas lineas de texto, por lo que utilizarla nos proporciona información útil para su clasificación.

# %%
df = pd.concat(dfs)
df.drop_duplicates(subset='url', keep='first', inplace=True)
df['category'] = df.apply(lambda row : cats_dict.get(row.tag, np.nan), axis=1)
#df['content'] = df['title'] + df['text']
df['content'] = df[['title', 'text']].agg('. '.join, axis=1)
df.head(3)
# Out:
#       id country media_outlet  \
# 0  49234   chile      horas24
# 3  49291   chile      horas24
# 6  49335   chile      horas24
#
#                                                  url  \
# 0  https://www.24horas.cl/coronavirus/tia-pikachu...
# 3  https://www.24horas.cl/nacional/rm-alcanza-sus...
# 6  https://www.24horas.cl/nacional/paro-de-camion...
#
#                                                title  \
# 0  "Tía Pikachu" por parte empadronado: "Estoy co...
# 3  RM alcanza sus mejores índices de calidad de a...
# 6  Paro de camioneros: Supermercados preocupados ...
#
#                                                 text        date          tag  \
# 0   Ha sufrido los embates del carro lanza aguas,...  2020-09-01  coronavirus
# 3   La ministra del Medio Ambiente, Carolina Schm...  2020-09-01     nacional
# 6   Esta jornada, la sexta de paralización de los...  2020-09-01     nacional
#
#    category                                            content
# 0  10-Salud  "Tía Pikachu" por parte empadronado: "Estoy co...
# 3       NaN  RM alcanza sus mejores índices de calidad de a...
# 6       NaN  Paro de camioneros: Supermercados preocupados ...

# %%
df.id.max()
# Out:
# 17798719

# %% [markdown]
# Almacenamos 30.000 de las noticias cuyo *url_tag* era muy general o no nos servía para asignarle una categoria. A estas noticias en una segunda etapa le aplicaremos LDA  para poder etiquetarlas y así aumentar la información de nuestro dataset inicial.

# %%
pd.set_option('display.max_colwidth', 120)
df = df[['id','url','title', 'content', 'category']]
unravel = df[df['category'].isna()]
(unravel.sample(n=30000, random_state=2)).to_csv('./intermediate_data/30k_sin_cat.csv', index=False)
df = df[df['category'].notna()]
final_df_link = df.drop(columns=['url'])
final_df_link.to_csv('./intermediate_data/final_df_link.csv', index=False)
final_df_link.head(3)
# Out:
#        id  \
# 0   49234
# 7   49349
# 22  49598
#
#                                                                                  title  \
# 0          "Tía Pikachu" por parte empadronado: "Estoy complicada de aquí a diciembre"
# 7            Sernac recibió más de 400 reclamos durante la primera jornada de CyberDay
# 22  ¿Cómo y dónde pueden abrir? Este miércoles reabren restaurantes en "modo pandemia"
#
#                                                                                                                     content  \
# 0   "Tía Pikachu" por parte empadronado: "Estoy complicada de aquí a diciembre".  Ha sufrido los embates del carro lanza...
# 7   Sernac recibió más de 400 reclamos durante la primera jornada de CyberDay.  Luego de la primera jornada de CyberDay,...
# 22  ¿Cómo y dónde pueden abrir? Este miércoles reabren restaurantes en "modo pandemia".  Este miércoles 2 de septiembre ...
#
#       category
# 0     10-Salud
# 7   2-Economía
# 22    10-Salud

# %% [markdown]
# Luego de esto, podemos ver que logramos etiquetar de buena manera una cantidad considerable de noticias, pero, existen categorías las cuales no pudimos proveerles una gran cantidad de noticias y existieron otras, particularmente la categoria *'5- Catástrofes y Accidentes'* que no fue posible, esto es debido a que los medios de prensa no tienen en sus URL una categoria para catastrofes o accidentes, siendo muy probable que se encuentren dentro de la categoría *'país'*.
#
# Por otro lado, debido al rango de fechas utilizado y a la forma de asignar categorías según la url, es posible que nuestro dataset esté sesgado, por ejemplo, en la categoría de *Salud*. Debido a que todas las noticias son a partir de Septiembre de 2020, fechas las cuales la gran mayoría de noticias son acerca de la pandemia del Coronavirus, por lo que noticias anteriores (o futuras) que hablen de la influenza u otras enfermedades que hayan pasado a segundo plano no sea bien clasificadas por el modelo final. Esto es aún más relevante al asignar la categoria **Salud** a las noticias con **coronavirus** en la url.

# %%
q="""SELECT category, count(*) FROM final_df_link GROUP BY category ORDER BY count(*) DESC;"""
url_cat_result=sqldf(q)
url_cat_result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1                    7-Deporte      6708
# 2      4-Ciencias_y_Tecnología      4225
# 3                   2-Economía      2636
# 4      3-Política_y_Conflictos      1923
# 5                     10-Salud       333
# 6            6-Cultura_y_Artes       185
# 7         8-Ecología_y_Planeta       135
# 8  9-Crimen_delitos_y_Justicia       130

# %% [markdown]
# Como es posible ver, la mitad de las categorías está considerablemente subrepresentada.

# %% [markdown]
# # 2. Aplicación de LDA a noticias no clasificadas

# %% [markdown]
# A las 30.000 noticias que guardamos antes le aplicamos LDA con 20 tópicos, creemos que es un buen número para poder apreciar una diferencia entre los grupos formados, debido a la gran cantidad de noticias a analizar.
#
# Posteriormente se realizará un clustering más fino con LDA adicional para aquellas noticias que queden en un tópico no muy bien definido o sin un tópico equivalente a las categorías objetivo.

# %%
import re
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
import spacy
# %matplotlib inline

# %%
df = pd.read_csv('./intermediate_data/30k_sin_cat.csv')
df.head(3)
# Out:
#         id  \
# 0  6354016
# 1  4685035
# 2  7317217
#
#                                                                                                                        url  \
# 0  https://www.latercera.com/que-pasa/noticia/vacuna-de-la-u-de-oxford-la-mas-avanzada-del-mundo-comenzara-sus-pruebas-...
# 1  https://www.latercera.com/nacional/noticia/caso-corpesca-tribunal-condena-a-jaime-orpis-por-cohecho-y-delitos-reiter...
# 2              https://www.meganoticias.cl/tendencias/323633-gianluca-vacchi-edad-sharon-fonseca-blu-jerusalema-rpx04.html
#
#                                                                                                  title  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile
# 1    Caso Corpesca: Tribunal condena a Jaime Orpis por cohecho y delitos reiterados de fraude al fisco
# 2         Desde un lujoso auto hasta viajes por el mundo: Así enamoró Gianluca Vacchi a Sharon Fonseca
#
#                                                                                                                    content  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile. La Universidad ...
# 1  Caso Corpesca: Tribunal condena a Jaime Orpis por cohecho y delitos reiterados de fraude al fisco. Uno de los casos ...
# 2  Desde un lujoso auto hasta viajes por el mundo: Así enamoró Gianluca Vacchi a Sharon Fonseca. Gianluca Vacchi (53) s...
#
#    category
# 0       NaN
# 1       NaN
# 2       NaN

# %%
def sent_to_words(sentences):
    for sentence in tqdm(sentences, desc="sentences to words"):
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
#import nltk
#nltk.download('stopwords')

#!python3 -m spacy download es_core_news_md

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
stop_words = stopwords.words('spanish')
nlp = spacy.load('es_core_news_md', disable=['parser', 'ner'])
def remove_stopwords(texts):
    desc = "removing stopwords"
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in tqdm(texts, desc=desc)]

def make_bigrams(texts, bigram_mod):
    return [bigram_mod[doc] for doc in tqdm(texts, desc="making bigrams")]

def make_trigrams(texts, bigram_mod, trigram_mod):
    return [trigram_mod[bigram_mod[doc]] for doc in tqdm(texts, desc="making trigrams")]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in tqdm(texts, desc="lemmatization"):
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
def get_ngrams(data_words):
    print('getting n-grams...')
    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    return bigram, trigram, bigram_mod, trigram_mod

# %%
def get_lemmatized_data(df):
    data = df.content.values.tolist()
    data = [re.sub(r'\s+', ' ', sent) for sent in tqdm(data, desc="replacing whitespaces")]
    data_words = list(sent_to_words(data))
    bigram, trigram, bigram_mod, trigram_mod = get_ngrams(data_words)
    data_words_nostops = remove_stopwords(data_words)
    data_words_bigrams = make_bigrams(data_words_nostops, bigram_mod)
    data_lemmatized = lemmatization(data_words_bigrams,
                                    allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
    return data_lemmatized

# %%
import pickle
try:
    with open ('./intermediate_data/data_lemmatized', 'rb') as fp:
        data_lemmatized = pickle.load(fp)
except FileNotFoundError:
    print('data_lemmatized not found...')
    data_lemmatized = get_lemmatized_data(df)
    with open('./intermediate_data/data_lemmatized', 'wb') as fp:
        pickle.dump(data_lemmatized, fp)

# %% [markdown]
# ### Entrenamiento del modelo de tópico con LDA
#
# - Entrenaremos un primer modelo de tópicos buscando un modelo con 20 tópicos.

# %%
model_filename = "./models/model_lda_20_topics.mm"
num_topics = 20
#lda_model = gensim.models.ldamodel.LdaModel.load("./models/model_lda_20_topics.mm", )

# %%
# %%time
try:
    lda_model = gensim.models.ldamodel.LdaModel.load(model_filename)
    id2word = corpora.Dictionary.load(model_filename + ".id2word")  
except FileNotFoundError:
    print("LDA model...")
    id2word = corpora.Dictionary(data_lemmatized)
    corpus = [id2word.doc2bow(text) for text in tqdm(data_lemmatized, desc='corpus')]
#     lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
#                                            id2word=id2word,
#                                            num_topics=num_topics, 
#                                            random_state=100,
#                                            update_every=1,
#                                            chunksize=100,
#                                            passes=10,
#                                            alpha='auto',
#                                            per_word_topics=True)
    
    lda_model = gensim.models.ldamulticore.LdaMulticore(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=num_topics, 
                                           random_state=num_topics,
                                           chunksize=100,
                                           passes=10,
                                           per_word_topics=True,
                                                   workers=4)
    lda_model.save(model_filename)
# Out:
# CPU times: user 84.1 ms, sys: 20.8 ms, total: 105 ms
# Wall time: 142 ms

# %%
def format_topics_documents(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(tqdm(ldamodel[corpus])):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
domtop_filename = './intermediate_data/df_dominant_topic.csv'
try:
    df_dominant_topic = pd.read_csv(domtop_filename)
except FileNotFoundError:
    df_topic_sents_keywords = format_topics_documents(lda_model, corpus, data_lemmatized)
    df_dominant_topic = df_topic_sents_keywords.reset_index()
    df_dominant_topic.to_csv(domtop_filename, index=False)
finally:    
    display(df_dominant_topic.head(5))
# Out:
#    index  Dominant_Topic  Perc_Contribution  \
# 0      0             7.0             0.9958
# 1      1             0.0             0.4724
# 2      2            14.0             0.8776
# 3      3             2.0             0.5394
# 4      4             2.0             0.3311
#
#                                                                        Topic_Keywords  \
# 0           vacuna, persona, dosis, salud, primero, virus, ano, paciente, medico, mas
# 1      caso, publico, derecho, abogado, tribunal, fiscal, ley, delito, recurso, hecho
# 2  instagrama_post, post_on, view_this, ano, post_shared, hacer, mas, hijo, ver, vida
# 3  persona, comuna, medida, fase, salud, semana, cuarentena, permiso, hora, autoridad
# 4  persona, comuna, medida, fase, salud, semana, cuarentena, permiso, hora, autoridad
#
#                                                                                                                          0
# 0  ['vacuna', 'avanzado', 'mundo', 'anunciar', 'inicio', 'prueba', 'laboratorio_astrazeneca', 'anunciar', 'vacuna', 'pr...
# 1  ['caso', 'cohecho', 'delitos_reiterado', 'fraude', 'fisco', 'caso', 'emblematico', 'financiamiento_irregular', 'poli...
# 2  ['lujoso', 'auto', 'mundo', 'enamorar', 'convertido', 'influencer', 'popular', 'redes_social', 'millón', 'seguidor',...
# 3  ['comercio', 'preocupado', 'retroceso', 'fase', 'manifesto', 'preocupacion', 'retroceso', 'fase', 'común', 'marco', ...
# 4  ['detener', 'persona', 'protestar', 'afuera', 'catedral', 'personal', 'primero', 'comisaria', 'carabineros', 'detene...

# %%
df_dominant_topic.columns = ['index', 'Dominant_Topic',
                             'Perc_Contribution',
                             'Keywords', 'text_list']

# %%
df_topics = pd.concat([df.drop(columns=['category']), df_dominant_topic[['Dominant_Topic',
                                                                         'Keywords',
                                                                         'text_list']]], axis=1)

# %%
df_topics['Dominant_Topic'] = df_topics['Dominant_Topic'].astype(int)
df_topics.head(3)
# Out:
#         id  \
# 0  6354016
# 1  4685035
# 2  7317217
#
#                                                                                                                        url  \
# 0  https://www.latercera.com/que-pasa/noticia/vacuna-de-la-u-de-oxford-la-mas-avanzada-del-mundo-comenzara-sus-pruebas-...
# 1  https://www.latercera.com/nacional/noticia/caso-corpesca-tribunal-condena-a-jaime-orpis-por-cohecho-y-delitos-reiter...
# 2              https://www.meganoticias.cl/tendencias/323633-gianluca-vacchi-edad-sharon-fonseca-blu-jerusalema-rpx04.html
#
#                                                                                                  title  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile
# 1    Caso Corpesca: Tribunal condena a Jaime Orpis por cohecho y delitos reiterados de fraude al fisco
# 2         Desde un lujoso auto hasta viajes por el mundo: Así enamoró Gianluca Vacchi a Sharon Fonseca
#
#                                                                                                                    content  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile. La Universidad ...
# 1  Caso Corpesca: Tribunal condena a Jaime Orpis por cohecho y delitos reiterados de fraude al fisco. Uno de los casos ...
# 2  Desde un lujoso auto hasta viajes por el mundo: Así enamoró Gianluca Vacchi a Sharon Fonseca. Gianluca Vacchi (53) s...
#
#    Dominant_Topic  \
# 0               7
# 1               0
# 2              14
#
#                                                                              Keywords  \
# 0           vacuna, persona, dosis, salud, primero, virus, ano, paciente, medico, mas
# 1      caso, publico, derecho, abogado, tribunal, fiscal, ley, delito, recurso, hecho
# 2  instagrama_post, post_on, view_this, ano, post_shared, hacer, mas, hijo, ver, vida
#
#                                                                                                                  text_list
# 0  ['vacuna', 'avanzado', 'mundo', 'anunciar', 'inicio', 'prueba', 'laboratorio_astrazeneca', 'anunciar', 'vacuna', 'pr...
# 1  ['caso', 'cohecho', 'delitos_reiterado', 'fraude', 'fisco', 'caso', 'emblematico', 'financiamiento_irregular', 'poli...
# 2  ['lujoso', 'auto', 'mundo', 'enamorar', 'convertido', 'influencer', 'popular', 'redes_social', 'millón', 'seguidor',...

# %% [markdown]
# # Análisis manual

# %%
from my_funcs import get_df_keywords
get_df_keywords(lda_model, num_topics)
# Out:
#              0           1                    2              3            4   \
# 0          caso       hacer              persona       ministro   carabinero
# 1       publico       decir               comuna     presidente     vehiculo
# 2       derecho         mas               medida        general        lugar
# 3       abogado         ver                 fase       interior      persona
# 4      tribunal       creer                salud     carabinero     personal
# 5        fiscal     persona               semana       director     detenido
# 6           ley       gente           cuarentena           jefe        hecho
# 7        delito      querer              permiso          hecho         arma
# 8       recurso         hoy                 hora          cargo     policial
# 9         hecho       tener            autoridad      autoridad    encontrar
# 10        dicho        bien                  fin          hacer         robo
# 11        parte         dar            sanitario       gobierno       sector
# 12   ministerio         ano               quedar         moneda      detener
# 13      proceso        solo                lunes         pinero       sujeto
# 14        corte     tambien                 paso          decir    conductor
# 15        penal      seguir             contagio     secretario  carabineros
# 16      defensa        cosa                hacer    institucion    accidente
# 17     decision         vez  region_metropolitán       sostener     realizar
# 18  antecedente  importante                pasar       nacional      disparo
# 19     justicia      tiempo                 caso  subsecretario        fuego
# 20     nacional    problema                común           ayer          dar
# 21      informe          ir                toque          nuevo       hombre
# 22     judicial       hecho                 solo        publico        luego
# 23        decir       pasar             realizar    carabineros         ruta
# 24    documento       vivir                  mas     mandatario     transito
#
#                 5            6            7                   8            9   \
# 0         proyecto          ano       vacuna                 ano        lugar
# 1         diputado      colegio      persona              delito          ano
# 2              ley       social        dosis               mujer          ver
# 3    parlamentario         vivo        salud             victima         zona
# 4         comision     programa      primero            imputado         obra
# 5           retiro     director        virus               hecho       ciudad
# 6            fondo     profesor          ano               joven       tierra
# 7          senador        nuevo     paciente              fiscal      espacio
# 8   constitucional        mujer       medico               menor      tercero
# 9          reforma      trabajo          mas              hombre       evento
# 10            voto  universidad   enfermedad              muerte     fenomeno
# 11         pensión     pandemio      estudio          carabinero       sesion
# 12  segundo_retiro   desarrollo        decir                caso         casa
# 13         aprobar     nacional    poblacion           encontrar        parte
# 14      presidente        clase  coronavirus  prision_preventivo          vez
# 15        gobierno   estudiante        mayor           homicidio          sol
# 16      iniciativo   entrevista       millón             policia  temperatura
# 17         primero      estudio       riesgo             persona   comentario
# 18       oposicion      chileno         caso             acusado      acceder
# 19          buscar    academico      proceso               luego     edificio
# 20           favor       alumno       llegar         antecedente       llegar
# 21         persona        junto          mes              pasado          luz
# 22        permitir     proyecto  laboratorio       investigacion        cerca
# 23           votar      proceso        hacer            detenido       objeto
# 24      establecer    educacion      recibir                 dar        hacer
#
#             10              11             12                13  \
# 0       millón      presidente        partido         violencia
# 1      empresa            voto      candidato           persona
# 2         pago        elección       politico     manifestación
# 3      persona       electoral  constituyente           octubre
# 4        pesos  estadounidense       primario  estallido_social
# 5     servicio       resultado          nuevo             sismo
# 6     realizar             ano  independiente              hora
# 7       dinero   internacional        proceso          protesta
# 8        pagar         primero       elección             grupo
# 9       contar            país        acuerdo              zona
# 10         mas         chileno     plebiscito          nacional
# 11    entregar        politico       eleccion       pic_twitter
# 12  trabajador           ganar        apruebo         incidente
# 13    contrato           decir             ex   plaza_baquedano
# 14     recibir       noviembre    candidatura           publico
# 15         ano         campana     presidente           generar
# 16     proceso      mandatario       distrito           temblor
# 17         mes       argentino   presidencial          detenido
# 18       hacer           lider        derecho           domingo
# 19     usuario         militar          listo         registrar
# 20       monto      venezolano      electoral           jornada
# 21        dato           mundo      oposicion             tarde
# 22     ingreso           unido       diputado      manifestante
# 23   beneficio        victoria             ir          magnitud
# 24     primero           medio           voto           viernes
#
#                  14           15            16             17            18  \
# 0   instagrama_post     incendio           mas        alcalde          caso
# 1           post_on      bombero           ano          local         nuevo
# 2         view_this       sector          agua        persona         cifra
# 3               ano  pic_twitter      producto           mesa         total
# 4       post_shared   emergencia         nuevo      municipio      contagio
# 5             hacer     vivienda       estudio     plebiscito         nivel
# 6               mas     trabajar        animal         vecino       persona
# 7              hijo        lugar      explicar         comuna       aumento
# 8               ver     afectado       tambien       votacion         salud
# 9              vida    encontrar    cientifico          votar        región
# 10            nuevo        fuego          tipo       servicio      nacional
# 11        shared_by         zona     encontrar          hacer           mas
# 12          primero      afectar      alimento            ano        ultimo
# 13            junto         hora         nivel          vocal        numero
# 14           contar    siniestro       sistema  municipalidad      pandemio
# 15           actriz       comuna        humano     transporte     registrar
# 16            dejar        llama          alto      municipal  casos_activo
# 17          familia      empresa          solo       regional         mayor
# 18            video       cuerpo  investigador         sector     fallecido
# 19           famoso         casa           uso            mas      paciente
# 20          artista      persona      utilizar      autoridad          alto
# 21              dar     mantener     ambiental         contar        region
# 22             foto         agua       empresa        octubre        semana
# 23            serie   voluntario       especie        publico        minsal
# 24         cantante       equipo       generar       asegurar     encontrar
#
#                                 19
# 0                           comuna
# 1                           region
# 2                      antofagasta
# 3                            común
# 4                             zona
# 5                            metro
# 6   nota_tabla_emol_tablaennoticio
# 7                         estación
# 8                             lago
# 9                      puente_alto
# 10                           tr_td
# 11                            isla
# 12                      extranjero
# 13                          biobio
# 14                         migrant
# 15                    casos_activo
# 16                           arico
# 17                         chillar
# 18                              px
# 19                           nuble
# 20                            tren
# 21                           norte
# 22                             mas
# 23                      disponible
# 24                      text_align

# %% [markdown]
#     1- Mundo
#     2- Economía
#     3- Política y Conflictos
#     4- Ciencias y Tecnología,
#     5- Catástrofes y Accidentes,
#     6- Cultura y Artes,
#     7- Deporte,
#     8- Ecología y Planeta,
#     9- Crimen, delitos y Justicia,
#     10- Salud

# %% [markdown]
# Analizando los 20 tópicos determinamos que cada uno de estos corresponde a las siguentes categorías propuestas.
#
# Algunos tópicos como el 6, 13 y 19 serán procesados con LDA nuevamente para poder mejorar su clasificación debido a que en esta primera instancia no fue posible clasificarlos de buena manera.

# %%
url_cat_result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1                    7-Deporte      6708
# 2      4-Ciencias_y_Tecnología      4225
# 3                   2-Economía      2636
# 4      3-Política_y_Conflictos      1923
# 5                     10-Salud       333
# 6            6-Cultura_y_Artes       185
# 7         8-Ecología_y_Planeta       135
# 8  9-Crimen_delitos_y_Justicia       130

# %%
# nos importan mas aquellas categorias menos numerosas
cats_dict = {0 : '9-Crimen_delitos_y_Justicia',
             3 : '3-Política_y_Conflictos',
             4 : '9-Crimen_delitos_y_Justicia',
             5 : '3-Política_y_Conflictos',
             7 : '10-Salud',
             8 : '9-Crimen_delitos_y_Justicia',
             10 : '2-Economía',
             11 : '3-Política_y_Conflictos',
             12 : '3-Política_y_Conflictos',
             15 : '5-Catástrofes_y_Accidentes'}

# el resto aun sin categoria
for i in range(0, num_topics):
    if i not in cats_dict.keys():
        cats_dict[i] = np.nan
        
cats_dict
df_topics['category'] = df_topics.apply(lambda row : cats_dict[row.Dominant_Topic], axis=1)
df_topics.head(10)
# Out:
#          id  \
# 0   6354016
# 1   4685035
# 2   7317217
# 3    167926
# 4   4738784
# 5   6318450
# 6   3966295
# 7   7323819
# 8  13384650
# 9   3966123
#
#                                                                                                                        url  \
# 0  https://www.latercera.com/que-pasa/noticia/vacuna-de-la-u-de-oxford-la-mas-avanzada-del-mundo-comenzara-sus-pruebas-...
# 1  https://www.latercera.com/nacional/noticia/caso-corpesca-tribunal-condena-a-jaime-orpis-por-cohecho-y-delitos-reiter...
# 2              https://www.meganoticias.cl/tendencias/323633-gianluca-vacchi-edad-sharon-fonseca-blu-jerusalema-rpx04.html
# 3  https://www.biobiochile.cl/noticias/nacional/region-de-la-araucania/2020/10/01/camara-de-comercio-preocupada-por-ret...
# 4  https://www.latercera.com/nacional/noticia/carabineros-detuvo-a-ocho-personas-en-protesta-a-las-afueras-de-la-catedr...
# 5  https://www.latercera.com/que-pasa/noticia/mujeres-manifiestan-mas-rechazo-que-los-hombres-a-la-vacuna-contra-el-cov...
# 6  https://www.elmostrador.cl/dia/2020/10/26/minsal-detalla-protocolos-para-uso-de-piscinas-cines-y-gimnasios-durante-l...
# 7               https://www.meganoticias.cl/tendencias/321922-video-virginia-demaria-hackeo-de-cuenta-instagram-mgx17.html
# 8                  https://www.emol.com/noticias/Nacional/2021/02/11/1011974/iCOVID-muestra-92-ocupacion-hospitalaria.html
# 9  https://www.elmostrador.cl/noticias/2020/10/26/plebiscito-coordinador-de-independientes-no-neutrales-sostiene-que-ha...
#
#                                                                                                                      title  \
# 0                      Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile
# 1                        Caso Corpesca: Tribunal condena a Jaime Orpis por cohecho y delitos reiterados de fraude al fisco
# 2                             Desde un lujoso auto hasta viajes por el mundo: Así enamoró Gianluca Vacchi a Sharon Fonseca
# 3                         Cámara de Comercio preocupada por retroceso a fase 2 de Temuco y otras 10 comuna de La Araucanía
# 4                                Carabineros detuvo a ocho personas en protesta a las afueras de la Catedral de Concepción
# 5                                              Mujeres manifiestan más rechazo que los hombres a la vacuna contra el Covid
# 6               Minsal detalla protocolos para uso de piscinas, cines y gimnasios durante la fase 4 del plan "Paso a Paso"
# 7                                    "Me están extorsionando, es espantoso": Virginia Demaría entre lágrimas revela hackeo
# 8  Informe iCOVID: Ocupación hospitalaria alcanza el 92,2% y se convierte en la cifra más alta desde que inició la pand...
# 9  Plebiscito: Coordinador de "Independientes No Neutrales" sostiene que "hay bastantes piedras en el camino para que l...
#
#                                                                                                                    content  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile. La Universidad ...
# 1  Caso Corpesca: Tribunal condena a Jaime Orpis por cohecho y delitos reiterados de fraude al fisco. Uno de los casos ...
# 2  Desde un lujoso auto hasta viajes por el mundo: Así enamoró Gianluca Vacchi a Sharon Fonseca. Gianluca Vacchi (53) s...
# 3  Cámara de Comercio preocupada por retroceso a fase 2 de Temuco y otras 10 comuna de La Araucanía. La Cámara de Comer...
# 4  Carabineros detuvo a ocho personas en protesta a las afueras de la Catedral de Concepción. Personal de la Primera Co...
# 5  Mujeres manifiestan más rechazo que los hombres a la vacuna contra el Covid. De acuerdo a lo que han informado las a...
# 6  Minsal detalla protocolos para uso de piscinas, cines y gimnasios durante la fase 4 del plan "Paso a Paso". Durante ...
# 7  "Me están extorsionando, es espantoso": Virginia Demaría entre lágrimas revela hackeo. La chef y figura televisiva V...
# 8  Informe iCOVID: Ocupación hospitalaria alcanza el 92,2% y se convierte en la cifra más alta desde que inició la pand...
# 9  Plebiscito: Coordinador de "Independientes No Neutrales" sostiene que "hay bastantes piedras en el camino para que l...
#
#    Dominant_Topic  \
# 0               7
# 1               0
# 2              14
# 3               2
# 4               2
# 5               7
# 6               2
# 7              14
# 8              18
# 9              12
#
#                                                                                                   Keywords  \
# 0                                vacuna, persona, dosis, salud, primero, virus, ano, paciente, medico, mas
# 1                           caso, publico, derecho, abogado, tribunal, fiscal, ley, delito, recurso, hecho
# 2                       instagrama_post, post_on, view_this, ano, post_shared, hacer, mas, hijo, ver, vida
# 3                       persona, comuna, medida, fase, salud, semana, cuarentena, permiso, hora, autoridad
# 4                       persona, comuna, medida, fase, salud, semana, cuarentena, permiso, hora, autoridad
# 5                                vacuna, persona, dosis, salud, primero, virus, ano, paciente, medico, mas
# 6                       persona, comuna, medida, fase, salud, semana, cuarentena, permiso, hora, autoridad
# 7                       instagrama_post, post_on, view_this, ano, post_shared, hacer, mas, hijo, ver, vida
# 8                              caso, nuevo, cifra, total, contagio, nivel, persona, aumento, salud, región
# 9  partido, candidato, politico, constituyente, primario, nuevo, independiente, proceso, elección, acuerdo
#
#                                                                                                                  text_list  \
# 0  ['vacuna', 'avanzado', 'mundo', 'anunciar', 'inicio', 'prueba', 'laboratorio_astrazeneca', 'anunciar', 'vacuna', 'pr...
# 1  ['caso', 'cohecho', 'delitos_reiterado', 'fraude', 'fisco', 'caso', 'emblematico', 'financiamiento_irregular', 'poli...
# 2  ['lujoso', 'auto', 'mundo', 'enamorar', 'convertido', 'influencer', 'popular', 'redes_social', 'millón', 'seguidor',...
# 3  ['comercio', 'preocupado', 'retroceso', 'fase', 'manifesto', 'preocupacion', 'retroceso', 'fase', 'común', 'marco', ...
# 4  ['detener', 'persona', 'protestar', 'afuera', 'catedral', 'personal', 'primero', 'comisaria', 'carabineros', 'detene...
# 5  ['mujer', 'manifestar', 'rechazo', 'hombre', 'vacuna', 'acuerdo', 'informado', 'autoridad', 'chileno', 'tendrar', 'a...
# 6  ['minsal', 'detallar', 'protocolo', 'uso', 'piscina', 'cines_gimnasios', 'paso', 'balance_diario', 'lunes', 'subsecr...
# 7  ['extorsionar', 'espantoso', 'virginia_demario', 'lagrima', 'revelar', 'hackeo', 'figurar', 'televisivo', 'virginia_...
# 8  ['ocupacion_hospitalario', 'alcanzar', 'convertir', 'cifra', 'alto', 'inicio', 'pandemio', 'jornada', 'version', 're...
# 9  ['plebiscito', 'coordinador', 'independiente', 'neutral', 'sostener', 'piedra', 'camino', 'manifesto', 'gente', 'hac...
#
#                       category
# 0                     10-Salud
# 1  9-Crimen_delitos_y_Justicia
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                     10-Salud
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9      3-Política_y_Conflictos

# %%
df_sin_topic = df_topics[df_topics.category.isna()]

# %%
df_topics = df_topics[['id','url','title', 'content', 'category']]
df_topics = df_topics[df_topics['category'].notna()]
df_topics.drop(columns=['url'], inplace=True)
df_topics.head(3)
# Out:
#         id  \
# 0  6354016
# 1  4685035
# 5  6318450
#
#                                                                                                  title  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile
# 1    Caso Corpesca: Tribunal condena a Jaime Orpis por cohecho y delitos reiterados de fraude al fisco
# 5                          Mujeres manifiestan más rechazo que los hombres a la vacuna contra el Covid
#
#                                                                                                                    content  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile. La Universidad ...
# 1  Caso Corpesca: Tribunal condena a Jaime Orpis por cohecho y delitos reiterados de fraude al fisco. Uno de los casos ...
# 5  Mujeres manifiestan más rechazo que los hombres a la vacuna contra el Covid. De acuerdo a lo que han informado las a...
#
#                       category
# 0                     10-Salud
# 1  9-Crimen_delitos_y_Justicia
# 5                     10-Salud

# %%
final_df_link = pd.read_csv('./intermediate_data/final_df_link.csv')
final_df_link.head(3)
# Out:
#       id  \
# 0  49234
# 1  49349
# 2  49598
#
#                                                                                 title  \
# 0         "Tía Pikachu" por parte empadronado: "Estoy complicada de aquí a diciembre"
# 1           Sernac recibió más de 400 reclamos durante la primera jornada de CyberDay
# 2  ¿Cómo y dónde pueden abrir? Este miércoles reabren restaurantes en "modo pandemia"
#
#                                                                                                                    content  \
# 0  "Tía Pikachu" por parte empadronado: "Estoy complicada de aquí a diciembre".  Ha sufrido los embates del carro lanza...
# 1  Sernac recibió más de 400 reclamos durante la primera jornada de CyberDay.  Luego de la primera jornada de CyberDay,...
# 2  ¿Cómo y dónde pueden abrir? Este miércoles reabren restaurantes en "modo pandemia".  Este miércoles 2 de septiembre ...
#
#      category
# 0    10-Salud
# 1  2-Economía
# 2    10-Salud

# %%
q="""SELECT category, count(*) FROM final_df_link GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1                    7-Deporte      6708
# 2      4-Ciencias_y_Tecnología      4225
# 3                   2-Economía      2636
# 4      3-Política_y_Conflictos      1923
# 5                     10-Salud       333
# 6            6-Cultura_y_Artes       185
# 7         8-Ecología_y_Planeta       135
# 8  9-Crimen_delitos_y_Justicia       130

# %%
q="""SELECT category, count(*) FROM df_topics GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0  9-Crimen_delitos_y_Justicia      7275
# 1      3-Política_y_Conflictos      5164
# 2                     10-Salud      1610
# 3                   2-Economía       862
# 4   5-Catástrofes_y_Accidentes       703

# %%
final_df = pd.concat([final_df_link, df_topics]).reset_index().drop(columns=['index'])

# %%
q="""SELECT category, count(*) FROM final_df GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1  9-Crimen_delitos_y_Justicia      7405
# 2      3-Política_y_Conflictos      7087
# 3                    7-Deporte      6708
# 4      4-Ciencias_y_Tecnología      4225
# 5                   2-Economía      3498
# 6                     10-Salud      1943
# 7   5-Catástrofes_y_Accidentes       703
# 8            6-Cultura_y_Artes       185
# 9         8-Ecología_y_Planeta       135

# %%
final_df.to_csv('./datasets/final_df_paso_1.csv', index=False)

# %%
df_topics.groupby('category').size()
# Out:
# category
# 10-Salud                       1610
# 2-Economía                      862
# 3-Política_y_Conflictos        5164
# 5-Catástrofes_y_Accidentes      703
# 9-Crimen_delitos_y_Justicia    7275
# dtype: int64

# %%
print(len(df_sin_topic))
df_sin_topic[['title', 'text_list', 'category']].head(5)
# Out:
# 14386
#                                                                                                         title  \
# 2                Desde un lujoso auto hasta viajes por el mundo: Así enamoró Gianluca Vacchi a Sharon Fonseca
# 3            Cámara de Comercio preocupada por retroceso a fase 2 de Temuco y otras 10 comuna de La Araucanía
# 4                   Carabineros detuvo a ocho personas en protesta a las afueras de la Catedral de Concepción
# 6  Minsal detalla protocolos para uso de piscinas, cines y gimnasios durante la fase 4 del plan "Paso a Paso"
# 7                       "Me están extorsionando, es espantoso": Virginia Demaría entre lágrimas revela hackeo
#
#                                                                                                                  text_list  \
# 2  ['lujoso', 'auto', 'mundo', 'enamorar', 'convertido', 'influencer', 'popular', 'redes_social', 'millón', 'seguidor',...
# 3  ['comercio', 'preocupado', 'retroceso', 'fase', 'manifesto', 'preocupacion', 'retroceso', 'fase', 'común', 'marco', ...
# 4  ['detener', 'persona', 'protestar', 'afuera', 'catedral', 'personal', 'primero', 'comisaria', 'carabineros', 'detene...
# 6  ['minsal', 'detallar', 'protocolo', 'uso', 'piscina', 'cines_gimnasios', 'paso', 'balance_diario', 'lunes', 'subsecr...
# 7  ['extorsionar', 'espantoso', 'virginia_demario', 'lagrima', 'revelar', 'hackeo', 'figurar', 'televisivo', 'virginia_...
#
#   category
# 2      NaN
# 3      NaN
# 4      NaN
# 6      NaN
# 7      NaN

# %% [markdown]
# Cerca del 50% del dataset sin categoría (post revision de urls) quedó con un tópico al que no logramos asignarle una de nuestras categorías objetivo.
#
# Adoptaremos dos enfoques diferentes para tratar de etiquetar correctamente estas noticias, priorizando las categorías menos numerosas con el objetivo de obtener un dataset relativamente balanceado.

# %% [markdown]
# ### LDA al subset completo

# %%
df_sin_topic.to_csv('./intermediate_data/df_sin_topic.csv', index=False)

# %% [markdown]
# # Clasificacion de subtopicos en el cuadernillo 2. ***paso_2_re_extraccion_lda.ipynb***
