# %% [markdown]
# # Generando el dataset para el proyecto de clasificacion de noticias
#
# Utilizamos los archivos csv proporcionados para crear nuestro dataset inicial (disponibles en noticias)

# %%
import pandas as pd
from os import listdir
from os.path import join
from tqdm import tqdm
from my_funcs import clean_and_tag
import re
from pandasql import sqldf
import numpy as np

# %%
pd.read_csv('./noticias/chile_2021-01.csv').head(3)
# Out:
#         id country media_outlet  \
# 0  3816243   chile  elmostrador
# 1  3816387   chile  elmostrador
# 2  3816512   chile  elmostrador
#
#                                                  url  \
# 0  https://www.elmostrador.cl/dia/2021/01/01/ley-...
# 1  https://www.elmostrador.cl/destacado/2021/01/0...
# 2  https://www.elmostrador.cl/dia/2021/01/01/829-...
#
#                                                title  \
# 0  Ley de Migración: diputada Núñez (RN) formula ...
# 1  2021 arranca con 3.588 nuevos contagios y 52 f...
# 2  829 personas fueron detenidas durante noche de...
#
#                                                 text        date    year  \
# 0  La diputada y vicepresidenta de Renovación Nac...  2021-01-01  2021.0
# 1  Según el reporte de hoy, el Ministerio de Salu...  2021-01-01  2021.0
# 2  Carabineros reportó que hasta las 06:00 am. de...  2021-01-01  2021.0
#
#    id_journalist
# 0            NaN
# 1            NaN
# 2            NaN

# %% [markdown]
#  Ya que estas noticias entregadas no se encuentran etiquetadas es necesario realizar un procesamiento previo para asignarles una categoria que nos permita entrenar y probar nuestros modelos de clasificación.
#
#  ### **Categorias a utilizar**: Se utilizarán las categorias propuestas en el enunciado del trabajo
#
# * 1- Mundo
# * 2- Economía
# * 3- Política y Conflictos
# * 4- Ciencias y Tecnología,
# * 5- Catástrofes y Accidentes,
# * 6- Cultura y Artes,
# * 7- Deporte,
# * 8- Ecología y Planeta,
# * 9- Crimen, delitos y Justicia,
# * 10- Salud
#
# ### Adoptamos dos estrategias para realizar esta tarea:
#
# 1. Asignarle una categoria a partir de la información de la url.
# 2. Utilizar LDA para encontrar topicos que correspondan a alguna categoria.

# %% [markdown]
# # 1. Etiquetado a partir de la informacion contenida en la url
#
# Debido a la gran cantidad de noticias, propusimos inicialmente utilizar esta metodologia para disminuir el trabajo inicial y aprovechando la propia información que nos proveen los medios de prensa.
#
# Todas las noticias en su URL vienen con una categoria propia del medio, aunque esta pueda diferir entre los medios (una misma noticias para un medio puede ser *nacional* pero para otro puede ser *cultura*) podemos clasificar incialmente utilizando esta información.

# %%
unique_url_tags = set()
folder = './noticias'
dfs = []
for archivo in tqdm(listdir(folder)):
    df = pd.read_csv(join(folder, archivo))
    corpus = clean_and_tag(df)
    dfs.append(corpus)
    for tag in corpus.tag.unique():
        unique_url_tags.add(tag)
# Out:
# 100%|██████████| 8/8 [00:02<00:00,  3.43it/s]

# %%
print(len(unique_url_tags))
list(unique_url_tags)[:10]
# Out:
# 83
# ['tendencias',
#  'noticiasbbc',
#  'eclipse-2020',
#  'mexico',
#  'nacional',
#  'tv',
#  'regiones',
#  'mercados',
#  'animal',
#  'mapuche']

# %% [markdown]
# ### Encontramos 83 tags distintos. Revisamos esta lista y asignamos manualmente una categoria a los url_tags que pertenecieran a alguna de las 10 categorias objetivo (este trabajo manual se encuentra en el archivo ```categorias - hojav2.csv```)

# %%
dm = pd.read_csv('./categorias - hojav2.csv')
dm.rename(columns={'Unnamed: 0':'tag'}, inplace=True)
vals = dm.iloc[:, 1:]
labels = vals[vals.max(axis=1)>0].idxmax(axis=1)
print(len(labels))
labels.head(5)
# Out:
# 40
# 1       8-Ecología_y_Planeta
# 2          6-Cultura_y_Artes
# 3    4-Ciencias_y_Tecnología
# 4    3-Política_y_Conflictos
# 8    4-Ciencias_y_Tecnología
# dtype: object

# %% [markdown]
# ### Utilizamos un diccionario para manejar de mejor manera las *tag_url* con las categorias propuestas

# %%
cats = pd.DataFrame(labels)
cats = cats.join(dm['tag'])
cats.rename(columns={0:'cat'}, inplace=True)
cats_dict = dict(zip(cats['tag'], cats['cat']))
list(cats_dict.items())[:5]
# Out:
# [('animal', '8-Ecología_y_Planeta'),
#  ('artes', '6-Cultura_y_Artes'),
#  ('Autos', '4-Ciencias_y_Tecnología'),
#  ('braga', '3-Política_y_Conflictos'),
#  ('ciencia-tecnologia', '4-Ciencias_y_Tecnología')]

# %% [markdown]
# Se agrega la columna ```category``` al dataframe rellenando con Nan.
# Creamos una columna *content* que contiene el titulo de la noticias más el cuerpo de esta.
# Esto se realizó debido a que el titulo contiene información sumamente importante la cual explica la idea principal de esta en muy pocas lineas de texto, por lo que utilizarla nos proporciona información util para su clasificación.

# %%
df = pd.concat(dfs)
df.drop_duplicates(subset='url', keep='first', inplace=True)
df['category'] = df.apply(lambda row : cats_dict.get(row.tag, np.nan), axis=1)
#df['content'] = df['title'] + df['text']
df['content'] = df[['title', 'text']].agg('. '.join, axis=1)
df.head(3)
# Out:
#       id country media_outlet  \
# 0  49234   chile      horas24
# 3  49291   chile      horas24
# 6  49335   chile      horas24
#
#                                                  url  \
# 0  https://www.24horas.cl/coronavirus/tia-pikachu...
# 3  https://www.24horas.cl/nacional/rm-alcanza-sus...
# 6  https://www.24horas.cl/nacional/paro-de-camion...
#
#                                                title  \
# 0  "Tía Pikachu" por parte empadronado: "Estoy co...
# 3  RM alcanza sus mejores índices de calidad de a...
# 6  Paro de camioneros: Supermercados preocupados ...
#
#                                                 text        date          tag  \
# 0   Ha sufrido los embates del carro lanza aguas,...  2020-09-01  coronavirus
# 3   La ministra del Medio Ambiente, Carolina Schm...  2020-09-01     nacional
# 6   Esta jornada, la sexta de paralización de los...  2020-09-01     nacional
#
#    category                                            content
# 0  10-Salud  "Tía Pikachu" por parte empadronado: "Estoy co...
# 3       NaN  RM alcanza sus mejores índices de calidad de a...
# 6       NaN  Paro de camioneros: Supermercados preocupados ...

# %% [markdown]
# Almacenamos 30.000 de las noticias cuyo *url_tag* era muy general o no nos servia para asignarle una categoria. A estas noticias en una segunda etapa le aplicaremos LDA  para poder etiquetarlas y asi aumentar la información de nuestro dataset inicial.

# %%
pd.set_option('display.max_colwidth', 120)
df = df[['id','url','title', 'content', 'category']]
unravel = df[df['category'].isna()]
(unravel.sample(n=30000, random_state=2)).to_csv('30k_sin_cat.csv')
df = df[df['category'].notna()]
final_df_link = df.drop(columns=['url'])
final_df_link.to_csv('final_df_link.csv')
final_df_link.head(3)
# Out:
#        id  \
# 0   49234
# 7   49349
# 22  49598
#
#                                                                                  title  \
# 0          "Tía Pikachu" por parte empadronado: "Estoy complicada de aquí a diciembre"
# 7            Sernac recibió más de 400 reclamos durante la primera jornada de CyberDay
# 22  ¿Cómo y dónde pueden abrir? Este miércoles reabren restaurantes en "modo pandemia"
#
#                                                                                                                     content  \
# 0   "Tía Pikachu" por parte empadronado: "Estoy complicada de aquí a diciembre".  Ha sufrido los embates del carro lanza...
# 7   Sernac recibió más de 400 reclamos durante la primera jornada de CyberDay.  Luego de la primera jornada de CyberDay,...
# 22  ¿Cómo y dónde pueden abrir? Este miércoles reabren restaurantes en "modo pandemia".  Este miércoles 2 de septiembre ...
#
#       category
# 0     10-Salud
# 7   2-Economía
# 22    10-Salud

# %% [markdown]
# Luego de esto, podemos ver que pudimos etiquetar de buena manera una cantidad considerable de noticias, pero, existen categorias las cuales no pudimos proveerles una gran cantidad de noticias y existieron otras, particularmente la categoria *5- Catástrofes y Accidentes* que no fue posible, esto es debido a que los medios de prensa no tienen en sus URL una categoria para catastrofes o accidentes.
#
# Por otro lado de esta manera es posible que nuestro dataset este sesgado, por ejemplo, en la categoria de Salud, todas las noticias son apartir de Septiembre de 2020, fechas las cuales la gran mayoria de noticias son acerca de la pandemia del Coronavirus, por lo que noticias anteriores que quizás hablan de la influenza u otras enfermedades las cuales anteriormete eran comunes pero desde esta fecha no, no sea bien clasificadas por este metodo.

# %%
q="""SELECT category, count(*) FROM final_df_link GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1                    7-Deporte      6708
# 2      4-Ciencias_y_Tecnología      4225
# 3                   2-Economía      2636
# 4      3-Política_y_Conflictos      1923
# 5                     10-Salud       333
# 6            6-Cultura_y_Artes       185
# 7         8-Ecología_y_Planeta       135
# 8  9-Crimen_delitos_y_Justicia       130

# %% [markdown]
# # 2. Aplicación de LDA a noticias no clasificadas

# %% [markdown]
# A las 30.000 noticias que guaradmos antes le aplicamos LDA con 20, creemos que es un buen número para poder apreciar una diferencia entre los grupos formados, debido a la gran cantidad de noticias a analizar

# %%
import re
from pprint import pprint
import nltk;
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
import string
# spacy for lemmatization
import spacy
# Plotting tools
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./30k_sin_cat.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head(3)
# Out:
#         id  \
# 0  6354016
# 1    26919
# 2   165091
#
#                                                                                                                        url  \
# 0  https://www.latercera.com/que-pasa/noticia/vacuna-de-la-u-de-oxford-la-mas-avanzada-del-mundo-comenzara-sus-pruebas-...
# 1  https://www.24horas.cl/nacional/comienza-la-postulacion-a-los-beneficios-estudiantiles-para-la-educacion-superior-20...
# 2  https://www.biobiochile.cl/noticias/nacional/region-de-los-lagos/2020/10/05/autoridades-regionales-de-los-lagos-preo...
#
#                                                                                                  title  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile
# 1               Comienza la postulación a los Beneficios Estudiantiles para la Educación Superior 2021
# 2         Autoridades regionales de Los Lagos preocupadas por falta de protección a la fauna en Chiloé
#
#                                                                                                                    content  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile. La Universidad ...
# 1  Comienza la postulación a los Beneficios Estudiantiles para la Educación Superior 2021. Este martes el Ministerio de...
# 2  Autoridades regionales de Los Lagos preocupadas por falta de protección a la fauna en Chiloé. Desde el Consejo Regio...
#
#    category
# 0       NaN
# 1       NaN
# 2       NaN

# %%
def sent_to_words(sentences):
    for sentence in tqdm(sentences, desc="sentences to words"):
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
stop_words = stopwords.words('spanish')
nlp = spacy.load('es_core_news_md', disable=['parser', 'ner'])
def remove_stopwords(texts):
    desc = "removing stopwords"
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in tqdm(texts, desc=desc)]

def make_bigrams(texts, bigram_mod):
    return [bigram_mod[doc] for doc in tqdm(texts, desc="making bigrams")]

def make_trigrams(texts, bigram_mod, trigram_mod):
    return [trigram_mod[bigram_mod[doc]] for doc in tqdm(texts, desc="making trigrams")]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in tqdm(texts, desc="lemmatization"):
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
def get_ngrams(data_words):
    print('getting n-grams...')
    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    return bigram, trigram, bigram_mod, trigram_mod

# %%
def get_lemmatized_data(df):
    data = df.content.values.tolist()
    data = [re.sub(r'\s+', ' ', sent) for sent in tqdm(data, desc="replacing whitespaces")]
    data_words = list(sent_to_words(data))
    bigram, trigram, bigram_mod, trigram_mod = get_ngrams(data_words)
    data_words_nostops = remove_stopwords(data_words)
    data_words_bigrams = make_bigrams(data_words_nostops, bigram_mod)
    data_lemmatized = lemmatization(data_words_bigrams,
                                    allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
    return data_lemmatized

# %%
import pickle
try:
    with open ('./data_lemmatized', 'rb') as fp:
        data_lemmatized = pickle.load(fp)
except FileNotFoundError:
    print('data_lemmatized not found...')
    data_lemmatized = get_lemmatized_data(df)
    with open('./data_lemmatized', 'wb') as fp:
        pickle.dump(data_lemmatized, fp)
# Out:
# data_lemmatized not found...
# replacing whitespaces: 100%|██████████| 30000/30000 [00:02<00:00, 10313.91it/s]
# sentences to words: 100%|██████████| 30000/30000 [00:17<00:00, 1754.16it/s]
# getting n-grams...
# removing stopwords: 100%|██████████| 30000/30000 [00:31<00:00, 965.92it/s]
# making bigrams: 100%|██████████| 30000/30000 [00:04<00:00, 7249.30it/s]
# lemmatization: 100%|██████████| 30000/30000 [03:37<00:00, 137.86it/s]

# %% [markdown]
# ### Entrenamiento del modelo de tópico con LDA
#
# - Entrenaremos un primer modelo de tópicos buscando un modelo con 20 tópicos.

# %%
model_file = "./models/model_lda_20_topics.mm"
num_topics = 20
#lda_model = gensim.models.ldamodel.LdaModel.load("./models/model_lda_20_topics.mm", )

# %%
try:
    lda_model = gensim.models.ldamodel.LdaModel.load("./models/model_lda_20_topics.mm")
    id2word = corpora.Dictionary.load(model_file + ".id2word")  
except FileNotFoundError:
    id2word = corpora.Dictionary(data_lemmatized) 
    lda_model = gensim.models.ldamulticore.LdaMulticore(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=num_topics, 
                                           random_state=num_topics,
                                           chunksize=100,
                                           passes=10,
                                           per_word_topics=True,
                                                   workers=4)
    lda_model.save(model_file)
texts = data_lemmatized
#corpus = [id2word.doc2bow(text) for text in tqdm(texts)]
corpus = [id2word.doc2bow(text) for text in tqdm(texts)]
# Out:
# 100%|██████████| 30000/30000 [00:02<00:00, 13917.02it/s]

# %%
def format_topics_documents(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(tqdm(ldamodel[corpus])):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
try:
    df_dominant_topic = pd.read_csv('./df_dominant_topic.csv')
except FileNotFoundError:
    df_topic_sents_keywords = format_topics_documents(lda_model, corpus, texts)

    # Format
    df_dominant_topic = df_topic_sents_keywords.reset_index()
    df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'text_list']
    df_dominant_topic.to_csv('./df_dominant_topic.csv')
    df_dominant_topic.head(20)
# Out:
# 100%|██████████| 30000/30000 [05:11<00:00, 96.21it/s]

# %%
df_dominant_topic.to_csv('./df_dominant_topic.csv')

# %%
df_topics = pd.concat([df.drop(columns=['category']), df_dominant_topic[['Dominant_Topic', 'Keywords', 'text_list']]], axis=1)

# %%
df_topics['Dominant_Topic'] = df_topics['Dominant_Topic'].astype(int)
df_topics.head(3)
# Out:
#         id  \
# 0  6354016
# 1    26919
# 2   165091
#
#                                                                                                                        url  \
# 0  https://www.latercera.com/que-pasa/noticia/vacuna-de-la-u-de-oxford-la-mas-avanzada-del-mundo-comenzara-sus-pruebas-...
# 1  https://www.24horas.cl/nacional/comienza-la-postulacion-a-los-beneficios-estudiantiles-para-la-educacion-superior-20...
# 2  https://www.biobiochile.cl/noticias/nacional/region-de-los-lagos/2020/10/05/autoridades-regionales-de-los-lagos-preo...
#
#                                                                                                  title  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile
# 1               Comienza la postulación a los Beneficios Estudiantiles para la Educación Superior 2021
# 2         Autoridades regionales de Los Lagos preocupadas por falta de protección a la fauna en Chiloé
#
#                                                                                                                    content  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile. La Universidad ...
# 1  Comienza la postulación a los Beneficios Estudiantiles para la Educación Superior 2021. Este martes el Ministerio de...
# 2  Autoridades regionales de Los Lagos preocupadas por falta de protección a la fauna en Chiloé. Desde el Consejo Regio...
#
#    Dominant_Topic  \
# 0               4
# 1               9
# 2              17
#
#                                                                                       Keywords  \
# 0      vacuna, salud, persona, dosis, primero, virus, paciente, decir, enfermedad, coronavirus
# 1           colegio, ano, educacion, profesor, estudiante, clase, tambien, salud, alumno, nino
# 2  alcalde, sector, incendio, trabajador, vecino, municipio, común, trabajar, trabajo, bombero
#
#                                                                                                                  text_list
# 0  [vacuna, avanzado, mundo, anunciar, inicio, prueba, laboratorio, astrazeneca, anunciar, vacuna, mas, prometedor, mun...
# 1  [comenzar, postulacion, beneficio, estudiantil, educacion_superior, martes, ministerio, educacion, iniciar, proceso,...
# 2  [autoridad, regional, lago, preocupado, falta, regional, mostrar, falta, proteccion, fauna, archipielago, ano, cerca...

# %% [markdown]
# # Análisis manual

# %%
from my_funcs import get_df_keywords
get_df_keywords(lda_model, num_topics)
# Out:
#                     0            1                2              3   \
# 0                 agua       region             caso      candidato
# 1            ambiental         zona          publico        partido
# 2               pueblo         hora           delito       primario
# 3            comunidad       biobio           fiscal  independiente
# 4   pueblos_originario          rio         fiscalia    candidatura
# 5           territorio     nacional       ministerio        alcalde
# 6               tierra      eclipse            hecho        acuerdo
# 7              derecho        sismo         tribunal             ir
# 8              mapuche        total              ano  constituyente
# 9                 isla       región         imputado       politico
# 10        organización    araucanio          abogado          nuevo
# 11             especie        norte      antecedente   presidencial
# 12      medio_ambiente         ruta      funcionario         sector
# 13   escanos_reservado  antofagasta  derechos_humano       distrito
# 14             planeta         lago            parte       eleccion
# 15                zona    kilometro          proceso      oposicion
# 16    pueblos_indigena     magnitud         justicia        tambien
# 17       internacional      atacama            penal       elección
# 18             indigén       arauco          octubre         unidad
# 19            indigena       evento          derecho             ex
# 20             escanos          sur            decir          pacto
# 21             acuerdo     regional         judicial          hacer
# 22           historico          ver            dicho          listo
# 23              dentro      generar            luego          lista
# 24             proceso     fenomeno          defensa          decir
#
#              4               5                6          7            8   \
# 0        vacuna        proyecto          post_on    chileno     servicio
# 1         salud        gobierno  instagrama_post        ano     producto
# 2       persona        ministro        view_this      nuevo      persona
# 3         dosis             ley      post_shared    primero    encontrar
# 4       primero        diputado        shared_by  argentino      usuario
# 5         virus      presidente              ano       obra      sistema
# 6      paciente           hacer               by      mundo       contar
# 7         decir   parlamentario             hijo      serie     realizar
# 8    enfermedad        comision            hacer  temporada      empresa
# 9   coronavirus          retiro             vida   historia         hora
# 10      estudio           fondo            nuevo   director        metro
# 11       medico         acuerdo              ver     contar         solo
# 12          ano           decir     redes_social      mejor        hacer
# 13       millón         reforma           actriz     ciudad       animal
# 14      tambien         senador           famoso       arte         tipo
# 15        mayor         persona             foto   nacional     alimento
# 16      proceso         primero          tambien      museo      acceder
# 17        hacer  constitucional          primero      ganar     problema
# 18       llegar         pensión           contar    artista  informacion
# 19          mas      iniciativo         seguidor   proyecto      tambien
# 20       riesgo         tambien            video     evento         dato
# 21    poblacion             hoy         cantante    cultura         caso
# 22  laboratorio  segundo_retiro            padre    virtual          red
# 23         caso          buscar         escribio   festival     explicar
# 24      recibir           nuevo            junto     premio   plataforma
#
#             9           10                11          12          13  \
# 0      colegio     persona        presidente       hecho         ano
# 1          ano        paso          ministro    vehiculo      millón
# 2    educacion      comuna          diputado       lugar       nuevo
# 3     profesor      medida          politico      hombre         mas
# 4   estudiante        fase                ex   encontrar       mayor
# 5        clase       salud             cargo     persona     estudio
# 6      tambien  cuarentena     parlamentario    detenido     tambien
# 7        salud        plan           senador         ano  desarrollo
# 8       alumno      semana              jefe       joven     empresa
# 9         nino     permiso             decir      sujeto       nivel
# 10  presencial   autoridad          gobierno        robo        solo
# 11      volver         fin          gabinete      muerte      social
# 12       decir   sanitario           defensa     victima       parte
# 13     escuela       hacer            moneda       luego     primero
# 14       hacer        hora  sebastian_pinera     detener    explicar
# 15     escolar       lunes            pinero      delito       mundo
# 16     trabajo      quedar             luego    fiscalia    programa
# 17   condición     tambien        mandatario   homicidio     sistema
# 18   actividad        solo         renunciar      fiscal        país
# 19     familia       toque            equipo   detencion   economico
# 20     proceso    contagio             dejar         dar         mes
# 21     acceder    realizar           partido        arma         vez
# 22      prueba       común          interior    imputado    nacional
# 23       tomar       salir           general    personal   principal
# 24       forma       decir        secretario  carabinero  cientifico
#
#                          14        15                16             17  \
# 0                     mujer     hacer        carabinero        alcalde
# 1                     menor     decir           persona         sector
# 2                    genero       ver          policial       incendio
# 3                 violencia     creer           general     trabajador
# 4               adolescente    querer         violencia         vecino
# 5                      nino     gente          detenido      municipio
# 6                  servicio       mas             hecho          común
# 7                      edad   persona          personal       trabajar
# 8                talcahuano       dar       institucion        trabajo
# 9                   familia   tambien           publico        bombero
# 10                 hospital      bien          interior       vivienda
# 11                  victima      solo     manifestación  municipalidad
# 12                     obra     tener             grupo    funcionario
# 13               residencia      cosa          director        empresa
# 14                 familiar       hoy             lugar       regional
# 15                   sexual       vez           policia      municipal
# 16                 denuncia    hablar       carabineros          lugar
# 17                denunciar     vivir           octubre      autoridad
# 18                 maltrato     pasar  estallido_social          salud
# 19                   sename   siempre           control     emergencia
# 20                    hogar      vida         incidente         comuna
# 21                      ano   momento            sector       afectado
# 22                   medico       ano              hora     valparaiso
# 23                    madre  entonces           tambien          parte
# 24  violencia_intrafamiliar     ahora            ataque       servicio
#
#                 18            19
# 0       plebiscito          caso
# 1             voto         nuevo
# 2            votar      contagio
# 3          proceso         total
# 4       presidente         cifra
# 5         politico         salud
# 6        electoral       persona
# 7          octubre         nivel
# 8          apruebo       aumento
# 9         votacion        región
# 10           nuevo      nacional
# 11        elección  casos_activo
# 12         derecho        numero
# 13       resultado        region
# 14         rechazo        semana
# 15    constitucion     registrar
# 16   constituyente         mayor
# 17         persona      paciente
# 18   participacion     fallecido
# 19           local          alto
# 20            mesa        ultimo
# 21      democracia        comuna
# 22         domingo   coronavirus
# 23  constitucional          tasa
# 24       ciudadano     encontrar

# %% [markdown]
#     1- Mundo
#     2- Economía
#     3- Política y Conflictos
#     4- Ciencias y Tecnología,
#     5- Catástrofes y Accidentes,
#     6- Cultura y Artes,
#     7- Deporte,
#     8- Ecología y Planeta,
#     9- Crimen, delitos y Justicia,
#     10- Salud

# %% [markdown]
# Analizando los 20 topicos determinamos que cada uno de estos corresponde a las siguentes categorias propuestas.
#
# Algunos topicos como el 6, 13 y 19 serán procesados con LDA nuevamente para poder mejorar su clasificación debido a que en esta primera instancia no fue posible clasificarlos de buena manera.

# %%
cats_dict = {1 : '8-Ecología_y_Planeta',
             2 : '9-Crimen_delitos_y_Justicia',
             3 : '3-Política_y_Conflictos',
             4 : '10-Salud',
             5 : '3-Política_y_Conflictos',
             7 : '6-Cultura_y_Artes',
             11 : '3-Política_y_Conflictos',
             12 : '9-Crimen_delitos_y_Justicia',
             14 : '9-Crimen_delitos_y_Justicia',
             16 : '9-Crimen_delitos_y_Justicia',
             17 : '5-Catástrofes_y_Accidentes',
             18 : '3-Política_y_Conflictos',}

# el resto aun sin categoria
for i in range(0, num_topics):
    if i not in cats_dict.keys():
        cats_dict[i] = np.nan
        
cats_dict
df_topics['category'] = df_topics.apply(lambda row : cats_dict[row.Dominant_Topic], axis=1)
df_topics.head(10)
# Out:
#         id  \
# 0  6354016
# 1    26919
# 2   165091
# 3  4676443
# 4  3834766
# 5  4760120
# 6  4382991
# 7  3994785
# 8  4610467
# 9  3831691
#
#                                                                                                                        url  \
# 0  https://www.latercera.com/que-pasa/noticia/vacuna-de-la-u-de-oxford-la-mas-avanzada-del-mundo-comenzara-sus-pruebas-...
# 1  https://www.24horas.cl/nacional/comienza-la-postulacion-a-los-beneficios-estudiantiles-para-la-educacion-superior-20...
# 2  https://www.biobiochile.cl/noticias/nacional/region-de-los-lagos/2020/10/05/autoridades-regionales-de-los-lagos-preo...
# 3                https://www.latercera.com/nacional/noticia/etiquetas-de-valparaiso-que-luchan/ULMBF7T2EFASBK7NODY6WGYM3Y/
# 4                                               https://www.meganoticias.cl/nacional/323580-balance-covid-chile-cgx02.html
# 5  https://www.latercera.com/nacional/noticia/camara-de-diputados-rechaza-por-falta-de-quorum-proyecto-de-educacion-sex...
# 6    https://www.elmostrador.cl/dia/2021/01/08/el-alcalde-de-londres-declara-a-la-capital-en-situacion-grave-por-covid-19/
# 7               https://www.meganoticias.cl/nacional/317914-muerte-mujer-venezolana-paso-no-habilitado-colchane-cgx02.html
# 8  https://www.latercera.com/nacional/noticia/ocupacion-de-camas-criticas-en-sistema-integrado-covid-llega-al-9248-y-pa...
# 9  https://www.meganoticias.cl/nacional/323659-rn-evopoli-partido-republicano-jose-antonio-kast-convencion-constituyent...
#
#                                                                                                                      title  \
# 0                      Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile
# 1                                   Comienza la postulación a los Beneficios Estudiantiles para la Educación Superior 2021
# 2                             Autoridades regionales de Los Lagos preocupadas por falta de protección a la fauna en Chiloé
# 3                                                                                       Etiquetas de Valparaíso que luchan
# 4                                          Balance coronavirus: Minsal reporta 3.685 casos nuevos, cifra más alta de julio
# 5                             Cámara de Diputados rechaza proyecto de educación sexual integral tras no alcanzar el quórum
# 6                                             El alcalde de Londres declara a la capital en situación "grave" por Covid-19
# 7                             Migrante muere intentando ingresar por paso no habilitado: Iba a reencontrarse con sus hijos
# 8  Ocupación de camas críticas en Sistema Integrado Covid llega al 92,48% y pacientes internados en UCI suben por 11° d...
# 9                            RN y Evópoli integran a partido de José Antonio Kast en pacto electoral para la Constituyente
#
#                                                                                                                    content  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile. La Universidad ...
# 1  Comienza la postulación a los Beneficios Estudiantiles para la Educación Superior 2021. Este martes el Ministerio de...
# 2  Autoridades regionales de Los Lagos preocupadas por falta de protección a la fauna en Chiloé. Desde el Consejo Regio...
# 3  Etiquetas de Valparaíso que luchan. Un milagroso bajativo de exportación, la clásica paleta de agua refrescante en l...
# 4  Balance coronavirus: Minsal reporta 3.685 casos nuevos, cifra más alta de julio. El ministerio de Salud entregó este...
# 5  Cámara de Diputados rechaza proyecto de educación sexual integral tras no alcanzar el quórum. La Cámara de Diputados...
# 6  El alcalde de Londres declara a la capital en situación "grave" por Covid-19. El alcalde de Londres, el laborista Sa...
# 7  Migrante muere intentando ingresar por paso no habilitado: Iba a reencontrarse con sus hijos. Una mujer de nacionali...
# 8  Ocupación de camas críticas en Sistema Integrado Covid llega al 92,48% y pacientes internados en UCI suben por 11° d...
# 9  RN y Evópoli integran a partido de José Antonio Kast en pacto electoral para la Constituyente. El Consejo General de...
#
#    Dominant_Topic  \
# 0               4
# 1               9
# 2              17
# 3              15
# 4              19
# 5               5
# 6              10
# 7              12
# 8              19
# 9               3
#
#                                                                                                   Keywords  \
# 0                  vacuna, salud, persona, dosis, primero, virus, paciente, decir, enfermedad, coronavirus
# 1                       colegio, ano, educacion, profesor, estudiante, clase, tambien, salud, alumno, nino
# 2              alcalde, sector, incendio, trabajador, vecino, municipio, común, trabajar, trabajo, bombero
# 3                                      hacer, decir, ver, creer, querer, gente, mas, persona, dar, tambien
# 4                              caso, nuevo, contagio, total, cifra, salud, persona, nivel, aumento, región
# 5          proyecto, gobierno, ministro, ley, diputado, presidente, hacer, parlamentario, comision, retiro
# 6                            persona, paso, comuna, medida, fase, salud, cuarentena, plan, semana, permiso
# 7                         hecho, vehiculo, lugar, hombre, encontrar, persona, detenido, ano, joven, sujeto
# 8                              caso, nuevo, contagio, total, cifra, salud, persona, nivel, aumento, región
# 9  candidato, partido, primario, independiente, candidatura, alcalde, acuerdo, ir, constituyente, politico
#
#                                                                                                                  text_list  \
# 0  [vacuna, avanzado, mundo, anunciar, inicio, prueba, laboratorio, astrazeneca, anunciar, vacuna, mas, prometedor, mun...
# 1  [comenzar, postulacion, beneficio, estudiantil, educacion_superior, martes, ministerio, educacion, iniciar, proceso,...
# 2  [autoridad, regional, lago, preocupado, falta, regional, mostrar, falta, proteccion, fauna, archipielago, ano, cerca...
# 3  [etiqueta, valparaiso, milagroso, bajativo, clasico, paletar, agua, refrescante, playa, rincon, colación, saludable,...
# 4  [balance, coronavirus, minsal_reportar, caso, nuevo, cifra, alto, julio, ministerio, salud, entrego, jueves, nuevo, ...
# 5  [rechazar, proyecto, educacion, sexual_integral, alcanzar, camarar, rechazo, faltar, quorum, voto, proyecto, estable...
# 6  [alcalde, declarar, capital, situacion, grave, londr, laborista, declarado, hoy, capital, britanico, situacion, grav...
# 7  [migrante, morir, intentar, ingresar, paso, habilitado, reencontrar él, hijo, mujer, nacionalidad_venezolán, falleci...
# 8  [ocupacion, camas_critica, sistema, integrado, llegar, pacientes_internado, subir, dia_consecutivo, porcentaje, ocup...
# 9  [integrar, partido, pacto, electoral, constituyente, general, renovacion_nacional, aprobo, pacto, electoral, convenc...
#
#                       category
# 0                     10-Salud
# 1                          NaN
# 2   5-Catástrofes_y_Accidentes
# 3                          NaN
# 4                          NaN
# 5      3-Política_y_Conflictos
# 6                          NaN
# 7  9-Crimen_delitos_y_Justicia
# 8                          NaN
# 9      3-Política_y_Conflictos

# %%
for i in range(num_topics):
    # agregar solo los category == nan
    if not isinstance(cats_dict[i], str) and np.isnan(cats_dict[i]):
        sub_df = df_topics[df_topics['Dominant_Topic'] == i]
        sub_df = sub_df[['id', 'title', 'content', 'Dominant_Topic', 'text_list']]
        sub_df.to_csv(f'./dominant_topics/dominant_topic{i}.csv')

# %%
final_df_topics = df_topics[['id','url','title', 'content', 'category']]
final_df_topics = final_df_topics[final_df_topics['category'].notna()]
final_df_topics.drop(columns=['url'], inplace=True)
final_df_topics.to_csv('final_df_topic.csv')
final_df_topics.head(3)
# Out:
#         id  \
# 0  6354016
# 2   165091
# 5  4760120
#
#                                                                                                  title  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile
# 2         Autoridades regionales de Los Lagos preocupadas por falta de protección a la fauna en Chiloé
# 5         Cámara de Diputados rechaza proyecto de educación sexual integral tras no alcanzar el quórum
#
#                                                                                                                    content  \
# 0  Vacuna de la U. de Oxford, la más avanzada del mundo, anuncia inicio de sus pruebas Fase 3 en Chile. La Universidad ...
# 2  Autoridades regionales de Los Lagos preocupadas por falta de protección a la fauna en Chiloé. Desde el Consejo Regio...
# 5  Cámara de Diputados rechaza proyecto de educación sexual integral tras no alcanzar el quórum. La Cámara de Diputados...
#
#                      category
# 0                    10-Salud
# 2  5-Catástrofes_y_Accidentes
# 5     3-Política_y_Conflictos

# %%
final_df_link = pd.read_csv('final_df_link.csv').drop(columns=['Unnamed: 0'])
final_df_link.head(3)
# Out:
#       id  \
# 0  49234
# 1  49349
# 2  49598
#
#                                                                                 title  \
# 0         "Tía Pikachu" por parte empadronado: "Estoy complicada de aquí a diciembre"
# 1           Sernac recibió más de 400 reclamos durante la primera jornada de CyberDay
# 2  ¿Cómo y dónde pueden abrir? Este miércoles reabren restaurantes en "modo pandemia"
#
#                                                                                                                    content  \
# 0  "Tía Pikachu" por parte empadronado: "Estoy complicada de aquí a diciembre".  Ha sufrido los embates del carro lanza...
# 1  Sernac recibió más de 400 reclamos durante la primera jornada de CyberDay.  Luego de la primera jornada de CyberDay,...
# 2  ¿Cómo y dónde pueden abrir? Este miércoles reabren restaurantes en "modo pandemia".  Este miércoles 2 de septiembre ...
#
#      category
# 0    10-Salud
# 1  2-Economía
# 2    10-Salud

# %%
final_df = pd.concat([final_df_link, final_df_topics]).reset_index().drop(columns=['index'])

# %%
q="""SELECT category, count(*) FROM final_df_topics GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0  9-Crimen_delitos_y_Justicia      8034
# 1      3-Política_y_Conflictos      5734
# 2                     10-Salud      1570
# 3   5-Catástrofes_y_Accidentes      1206
# 4         8-Ecología_y_Planeta       556
# 5            6-Cultura_y_Artes       363

# %%
q="""SELECT category, count(*) FROM final_df_link GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#                       category  count(*)
# 0                      1-Mundo      8609
# 1                    7-Deporte      6708
# 2      4-Ciencias_y_Tecnología      4225
# 3                   2-Economía      2636
# 4      3-Política_y_Conflictos      1923
# 5                     10-Salud       333
# 6            6-Cultura_y_Artes       185
# 7         8-Ecología_y_Planeta       135
# 8  9-Crimen_delitos_y_Justicia       130

# %% [markdown]
# # Clasificacion de subtopicos en el cuadernillo 2. ***paso_2_re_extraccion_lda.ipynb***
